# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import griddata
from math import radians, sin, cos, sqrt, atan2
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import GridSearchCV
from scipy.spatial.distance import pdist, squareform
import dask.array as da
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score
from math import radians, sin, cos, sqrt, atan2
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from joblib import Parallel, delayed
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import StandardScaler


#Extra settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings("ignore")

# %%
#Loading train and test data
try:
    train_df=pd.read_csv('/home/anuragverma/Desktop/Kaggle/GeoAI Ground-level NO2 _Zindi/Datasets/Train.csv')
    test_df=pd.read_csv('/home/anuragverma/Desktop/Kaggle/GeoAI Ground-level NO2 _Zindi/Datasets/Test.csv')
    print("Train df shape: " ,train_df.shape)
    print("Test df shape: ", test_df.shape)

except FileNotFoundError:
    print('File not loaded')
# Out:
# Train df shape:  (86584, 14)
# Test df shape:  (6576, 13)

# %%
def Prep_linear(df1,numeric_columns_linear):
    df=df1.copy()

    
    for col in numeric_columns_linear:
        # Fill missing values temporarily using linear interpolation
        data_interpolated = df[col].interpolate(method='linear')
        
        # Handle cases where interpolation might still leave NaNs at the ends
        if data_interpolated.isna().sum() > 0:
            data_interpolated.fillna(method='bfill', inplace=True)
            data_interpolated.fillna(method='ffill', inplace=True)

        # Decompose the time series to extract the trend component
        decomposition = seasonal_decompose(data_interpolated, model='additive', period=30)
        trend = decomposition.trend
        
        # Handle cases where the trend might still have NaNs at the ends
        trend.fillna(method='bfill', inplace=True)
        trend.fillna(method='ffill', inplace=True)

        # Replace original NaN values with the trend component
        df[col] = df[col].combine_first(trend)
        
        # Fill any remaining NaN values with the mean of the column
        df[col].fillna(value=df[col].mean(),inplace=True)

    return df

def Prep_linear_test(df1,numeric_columns_linear):
    df=df1.copy()
    
    
    for col in numeric_columns_linear:
        # Fill missing values temporarily using linear interpolation
        data_interpolated = df[col].interpolate(method='linear')
        
        # Handle cases where interpolation might still leave NaNs at the ends
        if data_interpolated.isna().sum() > 0:
            data_interpolated.fillna(method='bfill', inplace=True)
            data_interpolated.fillna(method='ffill', inplace=True)

        # Decompose the time series to extract the trend component
        decomposition = seasonal_decompose(data_interpolated, model='additive', period=30)
        trend = decomposition.trend
        
        # Handle cases where the trend might still have NaNs at the ends
        trend.fillna(method='bfill', inplace=True)
        trend.fillna(method='ffill', inplace=True)

        # Replace original NaN values with the trend component
        df[col] = df[col].combine_first(trend)
        
        # Fill any remaining NaN values with the mean of the column
        df[col].fillna(value=df[col].mean(),inplace=True)

    return df

#Testingtg cubic interpolcation second



def Prep_spline(df1,numeric_columns_spline):
    df=df1.copy()
    
    
    for col in numeric_columns_spline:
        # Fill missing values temporarily using linear interpolation
        data_interpolated = df[col].interpolate(method='spline',order=2)
        
        # Handle cases where interpolation might still leave NaNs at the ends
        if data_interpolated.isna().sum() > 0:
            data_interpolated.fillna(method='bfill', inplace=True)
            data_interpolated.fillna(method='ffill', inplace=True)

        # Decompose the time series to extract the trend component
        decomposition = seasonal_decompose(data_interpolated, model='additive', period=30)
        trend = decomposition.trend
        
        # Handle cases where the trend might still have NaNs at the ends
        trend.fillna(method='bfill', inplace=True)
        trend.fillna(method='ffill', inplace=True)

        # Replace original NaN values with the trend component
        df[col] = df[col].combine_first(trend)
        
        # Fill any remaining NaN values with the mean of the column
        df[col].fillna(value=df[col].mean(),inplace=True)

    return df

# %%
numeric_columns_spline =['NO2_strat','NO2_total','NO2_trop']
numeric_columns_linear_train =['Precipitation','LST','AAI','CloudFraction','TropopausePressure','GT_NO2']
numeric_columns_linear_test =['Precipitation','LST','AAI','CloudFraction','TropopausePressure']

# %%
train_model3_df_prep_mix=Prep_linear(train_df,numeric_columns_linear_train)
train_model3_df_prep_mix=Prep_spline(train_model3_df_prep_mix,numeric_columns_spline)

test_model3_df_prep_mix=Prep_linear_test(test_df,numeric_columns_linear_test)
test_model3_df_prep_mix=Prep_spline(test_model3_df_prep_mix,numeric_columns_spline)

# Select only numeric columns for both train and test datasets
train_model3_df_prep_mix = train_model3_df_prep_mix.select_dtypes(include=['number'])
test_model3_df_prep_mix = test_model3_df_prep_mix.select_dtypes(include=['number'])

# Separate the target variable 'GT_NO2' from the features in the training dataset
train_model3_df_prep_mix_GT_NO2_mix = train_model3_df_prep_mix['GT_NO2']
train_model3_df_prep_mix = train_model3_df_prep_mix.drop('GT_NO2', axis=1)

#Checking skewness for all cols.
Skewed_cols=train_model3_df_prep_mix.skew()[abs(train_model3_df_prep_mix.skew())>0.5].index.to_list()
Skewed_cols.remove('LON')
print(train_model3_df_prep_mix.skew()[abs(train_model3_df_prep_mix.skew())>0.5])
print('\n')
print(Skewed_cols)
print('\n')

#GT_NO2 is also skewed
print(train_df['GT_NO2'].skew())

#Best till now 10.53
# Out:
# LON              0.911077
# Precipitation    4.569618
# CloudFraction    1.236881
# NO2_total        4.169193
# NO2_trop         2.935214
# dtype: float64
#
#
# ['Precipitation', 'CloudFraction', 'NO2_total', 'NO2_trop']
#
#
# 1.507939283863649

# %%
train_model3_df_prep_mix_GT_NO2_mix.isnull().sum()
# Out:
# 0

# %%
train_df.head(5)
# Out:
#     ID_Zindi    Date    ID        LAT        LON  Precipitation  LST  \
# 0  ID_ENTGC7  1/1/19  PD01  45.601585  11.903551       0.000000  NaN
# 1  ID_8JCCXC  1/1/19  PD04  45.371005  11.840830       3.047342  NaN
# 2  ID_V3136Z  1/1/19  RO01  45.045825  12.060869       0.000000  NaN
# 3  ID_KRVZDJ  1/1/19  RO02  45.104075  11.553241       1.200467  NaN
# 4  ID_PR351A  1/1/19  RO03  45.038758  11.790152       1.274564  NaN
#
#         AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# 0  0.230527       0.559117   0.000024   0.000117       NaN
# 1 -0.074006       0.869309   0.000024   0.000127       NaN
# 2  0.024470       0.674160   0.000024   0.000086       NaN
# 3 -0.010442       0.920054   0.000024   0.000124       NaN
# 4 -0.176178       0.747464   0.000024   0.000116       NaN
#
#    TropopausePressure  GT_NO2
# 0         14440.82126    31.0
# 1         14441.79815    42.0
# 2         14437.38294    31.0
# 3         14440.83831    30.0
# 4         14438.79037    58.0

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted=train_model3_df_prep_mix.copy()
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted=test_model3_df_prep_mix.copy()

train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['Date']=train_df['Date'].copy()
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['ID_Zindi']=train_df['ID_Zindi'].copy()

test_model3_df_prep_mix_roll_wind_mean_stddev_sorted['Date']=test_df['Date'].copy()
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted['ID_Zindi']=test_df['ID_Zindi'].copy()

#We will be sorting by date so creating a ordered PK to sort it back
# Create an ordered PK
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['PK'] = range(1, len(train_model3_df_prep_mix_roll_wind_mean_stddev_sorted) + 1)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted['PK'] = range(1, len(test_model3_df_prep_mix_roll_wind_mean_stddev_sorted) + 1)


# Ensure 'Date' is in datetime format
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['Date'] = pd.to_datetime(train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['Date'])
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted['Date'] = pd.to_datetime(test_model3_df_prep_mix_roll_wind_mean_stddev_sorted['Date'])

# Sort by 'LAT', 'LON', and 'Date'
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted = train_model3_df_prep_mix_roll_wind_mean_stddev_sorted.sort_values(by=['LAT', 'LON', 'Date'])
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted = test_model3_df_prep_mix_roll_wind_mean_stddev_sorted.sort_values(by=['LAT', 'LON', 'Date'])

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted.head(5)
# Out:
#             LAT        LON  Precipitation         LST       AAI  \
# 69    44.924694  10.517502       0.000000  280.675857  0.286079
# 2518  44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730  44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179  44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549  44.924694  10.517502       0.000000  303.260000 -0.987795
#
#       CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69         0.954099   0.000024   0.000395  0.000140         14436.75358
# 2518       0.970421   0.000030   0.000873  0.000143         16692.01730
# 4730       0.273483   0.000037   0.000171  0.000119         19279.33913
# 7179       0.109390   0.000050   0.000152  0.000102         19286.55321
# 9549       0.000008   0.000063   0.000116  0.000053         19282.00083
#
#            Date   ID_Zindi    PK
# 69   2019-01-01  ID_ELHEMB    70
# 2518 2019-01-02  ID_RLD66Y  2519
# 4730 2019-01-03  ID_JLN5ZY  4731
# 7179 2019-01-04  ID_YC6QCK  7180
# 9549 2019-01-05  ID_I56YD1  9550

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted.head(5)
# Out:
#           LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 3   45.131947  10.015742       1.928031  279.369667  0.132952       0.756917
# 9   45.131947  10.015742       0.000000  279.369667 -0.626818       0.391763
# 15  45.131947  10.015742       0.000000  277.440000 -0.845165       0.000761
# 21  45.131947  10.015742       0.000000  279.066222 -1.342863       0.049850
# 27  45.131947  10.015742       1.928031  276.580000 -0.621298       0.061076
#
#     NO2_strat  NO2_total  NO2_trop  TropopausePressure       Date   ID_Zindi  \
# 3    0.000024   0.000266  0.000114         14443.09006 2019-01-01  ID_QGSNTZ
# 9    0.000034   0.000223  0.000114         19330.30774 2019-01-02  ID_8JASJD
# 15   0.000030   0.000120  0.000090         22279.10381 2019-01-03  ID_C2YTPV
# 21   0.000020   0.000122  0.000102         16744.84559 2019-01-04  ID_O6FGA6
# 27   0.000018   0.000255  0.000193         16732.51469 2019-01-05  ID_ANJZBA
#
#     PK
# 3    4
# 9   10
# 15  16
# 21  22
# 27  28

# %%
# train_model3_df_prep_mix_roll_wind_mean_stddev_sorted[train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['LAT']==44.99954599].head(100)
Rolling_window=3
Cols_for_Rolling_Window=train_model3_df_prep_mix.columns.to_list()
Cols_for_Rolling_Window.remove('LAT')
Cols_for_Rolling_Window.remove('LON')

# %%
train_model3_df_prep_mix.head(5)
# Out:
#          LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 0  45.601585  11.903551       0.000000  280.097333  0.230527       0.559117
# 1  45.371005  11.840830       3.047342  280.097333 -0.074006       0.869309
# 2  45.045825  12.060869       0.000000  280.097333  0.024470       0.674160
# 3  45.104075  11.553241       1.200467  280.097333 -0.010442       0.920054
# 4  45.038758  11.790152       1.274564  280.097333 -0.176178       0.747464
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure
# 0   0.000024   0.000117  0.000131         14440.82126
# 1   0.000024   0.000127  0.000131         14441.79815
# 2   0.000024   0.000086  0.000131         14437.38294
# 3   0.000024   0.000124  0.000131         14440.83831
# 4   0.000024   0.000116  0.000131         14438.79037

# %%
# Function to apply rolling mean to specified columns
# Function to apply rolling mean and stddev to specified columns
def apply_rolling_stats(df, group_cols, cols_to_roll, window=3):
    for col in cols_to_roll:
        new_mean_col_name = f'Rolling_Mean_{col}'
        new_stddev_col_name = f'Rolling_Stddev_{col}'
        df[new_mean_col_name] = df.groupby(group_cols)[col].transform(lambda x: x.rolling(window=window).mean())
        df[new_stddev_col_name] = df.groupby(group_cols)[col].transform(lambda x: x.rolling(window=window).std())
        df[new_mean_col_name].fillna(method='bfill', inplace=True)
        df[new_mean_col_name].fillna(method='ffill', inplace=True)
        df[new_stddev_col_name].fillna(method='bfill', inplace=True)
        df[new_stddev_col_name].fillna(method='ffill', inplace=True)
    return df

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted=apply_rolling_stats(train_model3_df_prep_mix_roll_wind_mean_stddev_sorted,['LAT','LON'],Cols_for_Rolling_Window,window=3)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted=apply_rolling_stats(test_model3_df_prep_mix_roll_wind_mean_stddev_sorted,['LAT','LON'],Cols_for_Rolling_Window,window=3)

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted[train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['LAT']==44.92469405].head(10)
#44.92469405
# Out:
#              LAT        LON  Precipitation         LST       AAI  \
# 69     44.924694  10.517502       0.000000  280.675857  0.286079
# 2518   44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730   44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179   44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549   44.924694  10.517502       0.000000  303.260000 -0.987795
# 11998  44.924694  10.517502       0.000000  305.520000 -1.123626
# 14368  44.924694  10.517502       0.000000  308.280000 -1.486456
# 16817  44.924694  10.517502       0.000000  305.820000 -1.519680
# 19266  44.924694  10.517502       0.000000  309.720000 -1.879356
# 21636  44.924694  10.517502       0.000000  298.460000 -1.289062
#
#        CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69          0.954099   0.000024   0.000395  0.000140        14436.753580
# 2518        0.970421   0.000030   0.000873  0.000143        16692.017300
# 4730        0.273483   0.000037   0.000171  0.000119        19279.339130
# 7179        0.109390   0.000050   0.000152  0.000102        19286.553210
# 9549        0.000008   0.000063   0.000116  0.000053        19282.000830
# 11998       0.000000   0.000061   0.000091  0.000030        16715.142730
# 14368       0.017318   0.000060   0.000105  0.000045         8614.530051
# 16817       0.022716   0.000062   0.000102  0.000040        14427.888730
# 19266       0.000000   0.000056   0.000092  0.000036        14426.716680
# 21636       0.042110   0.000047   0.000080  0.000033        13056.621470
#
#             Date   ID_Zindi     PK  Rolling_Mean_Precipitation  \
# 69    2019-01-01  ID_ELHEMB     70                    2.737313
# 2518  2019-01-02  ID_RLD66Y   2519                    2.737313
# 4730  2019-01-03  ID_JLN5ZY   4731                    2.737313
# 7179  2019-01-04  ID_YC6QCK   7180                    2.737313
# 9549  2019-01-05  ID_I56YD1   9550                    0.000000
# 11998 2019-01-06  ID_FKZF1C  11999                    0.000000
# 14368 2019-01-07  ID_BBYHQH  14369                    0.000000
# 16817 2019-01-08  ID_W8OH93  16818                    0.000000
# 19266 2019-01-09  ID_FYHRGF  19267                    0.000000
# 21636 2019-01-10  ID_NL8HHQ  21637                    0.000000
#
#        Rolling_Stddev_Precipitation  Rolling_Mean_LST  Rolling_Stddev_LST  \
# 69                         4.741165        284.897063            8.112070
# 2518                       4.741165        284.897063            8.112070
# 4730                       4.741165        284.897063            8.112070
# 7179                       4.741165        289.418444            8.359263
# 9549                       0.000000        297.249778            5.205007
# 11998                      0.000000        301.006667            5.968059
# 14368                      0.000000        305.686667            2.514147
# 16817                      0.000000        306.540000            1.514332
# 19266                      0.000000        307.940000            1.972105
# 21636                      0.000000        304.666667            5.717913
#
#        Rolling_Mean_AAI  Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 69            -0.393219            0.607947                    0.732668
# 2518          -0.393219            0.607947                    0.732668
# 4730          -0.393219            0.607947                    0.732668
# 7179          -0.786601            0.179379                    0.451098
# 9549          -0.922692            0.056517                    0.127627
# 11998         -1.001830            0.115421                    0.036466
# 14368         -1.199292            0.257798                    0.005776
# 16817         -1.376587            0.219700                    0.013345
# 19266         -1.628497            0.217884                    0.013345
# 21636         -1.562699            0.297489                    0.021609
#
#        Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 69                         0.397750                0.000031
# 2518                       0.397750                0.000031
# 4730                       0.397750                0.000031
# 7179                       0.457169                0.000039
# 9549                       0.137646                0.000050
# 11998                      0.063154                0.000058
# 14368                      0.009996                0.000061
# 16817                      0.011868                0.000061
# 19266                      0.011868                0.000059
# 21636                      0.021077                0.000055
#
#        Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 69                     0.000007                0.000480
# 2518                   0.000007                0.000480
# 4730                   0.000007                0.000480
# 7179                   0.000010                0.000399
# 9549                   0.000013                0.000146
# 11998                  0.000007                0.000120
# 14368                  0.000001                0.000104
# 16817                  0.000001                0.000099
# 19266                  0.000003                0.000100
# 21636                  0.000008                0.000091
#
#        Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  \
# 69                     0.000359               0.000134
# 2518                   0.000359               0.000134
# 4730                   0.000359               0.000134
# 7179                   0.000411               0.000121
# 9549                   0.000028               0.000091
# 11998                  0.000031               0.000062
# 14368                  0.000013               0.000043
# 16817                  0.000007               0.000038
# 19266                  0.000007               0.000040
# 21636                  0.000011               0.000036
#
#        Rolling_Stddev_NO2_trop  Rolling_Mean_TropopausePressure  \
# 69                    0.000013                     16802.703337
# 2518                  0.000013                     16802.703337
# 4730                  0.000013                     16802.703337
# 7179                  0.000021                     18419.303213
# 9549                  0.000034                     19282.631057
# 11998                 0.000037                     18427.898923
# 14368                 0.000011                     14870.557870
# 16817                 0.000007                     13252.520504
# 19266                 0.000005                     12489.711820
# 21636                 0.000004                     13970.408960
#
#        Rolling_Stddev_TropopausePressure
# 69                           2423.189479
# 2518                         2423.189479
# 4730                         2423.189479
# 7179                         1495.877829
# 9549                            3.648099
# 11998                        1483.292120
# 14368                        5567.818530
# 16817                        4176.254218
# 19266                        3356.005908
# 21636                         791.363397

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted.head(6)
# Out:
#           LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 3   45.131947  10.015742       1.928031  279.369667  0.132952       0.756917
# 9   45.131947  10.015742       0.000000  279.369667 -0.626818       0.391763
# 15  45.131947  10.015742       0.000000  277.440000 -0.845165       0.000761
# 21  45.131947  10.015742       0.000000  279.066222 -1.342863       0.049850
# 27  45.131947  10.015742       1.928031  276.580000 -0.621298       0.061076
# 33  45.131947  10.015742       0.000000  279.380000 -0.634519       0.040908
#
#     NO2_strat  NO2_total  NO2_trop  TropopausePressure       Date   ID_Zindi  \
# 3    0.000024   0.000266  0.000114         14443.09006 2019-01-01  ID_QGSNTZ
# 9    0.000034   0.000223  0.000114         19330.30774 2019-01-02  ID_8JASJD
# 15   0.000030   0.000120  0.000090         22279.10381 2019-01-03  ID_C2YTPV
# 21   0.000020   0.000122  0.000102         16744.84559 2019-01-04  ID_O6FGA6
# 27   0.000018   0.000255  0.000193         16732.51469 2019-01-05  ID_ANJZBA
# 33   0.000022   0.000181  0.000172         16733.67227 2019-01-06  ID_ZOMAXE
#
#     PK  Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  \
# 3    4                    0.642677                      1.113149
# 9   10                    0.642677                      1.113149
# 15  16                    0.642677                      1.113149
# 21  22                    0.000000                      0.000000
# 27  28                    0.642677                      1.113149
# 33  34                    0.642677                      1.113149
#
#     Rolling_Mean_LST  Rolling_Stddev_LST  Rolling_Mean_AAI  \
# 3         278.726444            1.114094         -0.446344
# 9         278.726444            1.114094         -0.446344
# 15        278.726444            1.114094         -0.446344
# 21        278.625296            1.037649         -0.938282
# 27        277.695407            1.262636         -0.936442
# 33        278.342074            1.534045         -0.866226
#
#     Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 3             0.513426                    0.383147
# 9             0.513426                    0.383147
# 15            0.513426                    0.383147
# 21            0.366992                    0.147458
# 27            0.369341                    0.037229
# 33            0.412832                    0.050612
#
#     Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 3                       0.378152                0.000029
# 9                       0.378152                0.000029
# 15                      0.378152                0.000029
# 21                      0.212993                0.000028
# 27                      0.032077                0.000023
# 33                      0.010105                0.000020
#
#     Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 3                   0.000005                0.000203
# 9                   0.000005                0.000203
# 15                  0.000005                0.000203
# 21                  0.000007                0.000155
# 27                  0.000006                0.000166
# 33                  0.000002                0.000186
#
#     Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 3                   0.000075               0.000106                 0.000014
# 9                   0.000075               0.000106                 0.000014
# 15                  0.000075               0.000106                 0.000014
# 21                  0.000059               0.000102                 0.000012
# 27                  0.000077               0.000128                 0.000056
# 33                  0.000067               0.000156                 0.000048
#
#     Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure
# 3                      18684.167203                        3957.764655
# 9                      18684.167203                        3957.764655
# 15                     18684.167203                        3957.764655
# 21                     19451.419047                        2769.116190
# 27                     18585.488030                        3198.771039
# 33                     16737.010850                           6.809725

# %%
#Now starting lag features
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1=train_model3_df_prep_mix_roll_wind_mean_stddev_sorted.copy()
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1=train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.sort_values(by=['LAT','LON','Date'])

test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1=test_model3_df_prep_mix_roll_wind_mean_stddev_sorted.copy()
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1=test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.sort_values(by=['LAT','LON','Date'])

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted[train_model3_df_prep_mix_roll_wind_mean_stddev_sorted['LAT']==44.92469405].head(6)
#44.92469405
# Out:
#              LAT        LON  Precipitation         LST       AAI  \
# 69     44.924694  10.517502       0.000000  280.675857  0.286079
# 2518   44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730   44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179   44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549   44.924694  10.517502       0.000000  303.260000 -0.987795
# 11998  44.924694  10.517502       0.000000  305.520000 -1.123626
#
#        CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69          0.954099   0.000024   0.000395  0.000140         14436.75358
# 2518        0.970421   0.000030   0.000873  0.000143         16692.01730
# 4730        0.273483   0.000037   0.000171  0.000119         19279.33913
# 7179        0.109390   0.000050   0.000152  0.000102         19286.55321
# 9549        0.000008   0.000063   0.000116  0.000053         19282.00083
# 11998       0.000000   0.000061   0.000091  0.000030         16715.14273
#
#             Date   ID_Zindi     PK  Rolling_Mean_Precipitation  \
# 69    2019-01-01  ID_ELHEMB     70                    2.737313
# 2518  2019-01-02  ID_RLD66Y   2519                    2.737313
# 4730  2019-01-03  ID_JLN5ZY   4731                    2.737313
# 7179  2019-01-04  ID_YC6QCK   7180                    2.737313
# 9549  2019-01-05  ID_I56YD1   9550                    0.000000
# 11998 2019-01-06  ID_FKZF1C  11999                    0.000000
#
#        Rolling_Stddev_Precipitation  Rolling_Mean_LST  Rolling_Stddev_LST  \
# 69                         4.741165        284.897063            8.112070
# 2518                       4.741165        284.897063            8.112070
# 4730                       4.741165        284.897063            8.112070
# 7179                       4.741165        289.418444            8.359263
# 9549                       0.000000        297.249778            5.205007
# 11998                      0.000000        301.006667            5.968059
#
#        Rolling_Mean_AAI  Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 69            -0.393219            0.607947                    0.732668
# 2518          -0.393219            0.607947                    0.732668
# 4730          -0.393219            0.607947                    0.732668
# 7179          -0.786601            0.179379                    0.451098
# 9549          -0.922692            0.056517                    0.127627
# 11998         -1.001830            0.115421                    0.036466
#
#        Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 69                         0.397750                0.000031
# 2518                       0.397750                0.000031
# 4730                       0.397750                0.000031
# 7179                       0.457169                0.000039
# 9549                       0.137646                0.000050
# 11998                      0.063154                0.000058
#
#        Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 69                     0.000007                0.000480
# 2518                   0.000007                0.000480
# 4730                   0.000007                0.000480
# 7179                   0.000010                0.000399
# 9549                   0.000013                0.000146
# 11998                  0.000007                0.000120
#
#        Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  \
# 69                     0.000359               0.000134
# 2518                   0.000359               0.000134
# 4730                   0.000359               0.000134
# 7179                   0.000411               0.000121
# 9549                   0.000028               0.000091
# 11998                  0.000031               0.000062
#
#        Rolling_Stddev_NO2_trop  Rolling_Mean_TropopausePressure  \
# 69                    0.000013                     16802.703337
# 2518                  0.000013                     16802.703337
# 4730                  0.000013                     16802.703337
# 7179                  0.000021                     18419.303213
# 9549                  0.000034                     19282.631057
# 11998                 0.000037                     18427.898923
#
#        Rolling_Stddev_TropopausePressure
# 69                           2423.189479
# 2518                         2423.189479
# 4730                         2423.189479
# 7179                         1495.877829
# 9549                            3.648099
# 11998                        1483.292120

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==44.92469405].head(6)
#44.92469405
# Out:
#              LAT        LON  Precipitation         LST       AAI  \
# 69     44.924694  10.517502       0.000000  280.675857  0.286079
# 2518   44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730   44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179   44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549   44.924694  10.517502       0.000000  303.260000 -0.987795
# 11998  44.924694  10.517502       0.000000  305.520000 -1.123626
#
#        CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69          0.954099   0.000024   0.000395  0.000140         14436.75358
# 2518        0.970421   0.000030   0.000873  0.000143         16692.01730
# 4730        0.273483   0.000037   0.000171  0.000119         19279.33913
# 7179        0.109390   0.000050   0.000152  0.000102         19286.55321
# 9549        0.000008   0.000063   0.000116  0.000053         19282.00083
# 11998       0.000000   0.000061   0.000091  0.000030         16715.14273
#
#             Date   ID_Zindi     PK  Rolling_Mean_Precipitation  \
# 69    2019-01-01  ID_ELHEMB     70                    2.737313
# 2518  2019-01-02  ID_RLD66Y   2519                    2.737313
# 4730  2019-01-03  ID_JLN5ZY   4731                    2.737313
# 7179  2019-01-04  ID_YC6QCK   7180                    2.737313
# 9549  2019-01-05  ID_I56YD1   9550                    0.000000
# 11998 2019-01-06  ID_FKZF1C  11999                    0.000000
#
#        Rolling_Stddev_Precipitation  Rolling_Mean_LST  Rolling_Stddev_LST  \
# 69                         4.741165        284.897063            8.112070
# 2518                       4.741165        284.897063            8.112070
# 4730                       4.741165        284.897063            8.112070
# 7179                       4.741165        289.418444            8.359263
# 9549                       0.000000        297.249778            5.205007
# 11998                      0.000000        301.006667            5.968059
#
#        Rolling_Mean_AAI  Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 69            -0.393219            0.607947                    0.732668
# 2518          -0.393219            0.607947                    0.732668
# 4730          -0.393219            0.607947                    0.732668
# 7179          -0.786601            0.179379                    0.451098
# 9549          -0.922692            0.056517                    0.127627
# 11998         -1.001830            0.115421                    0.036466
#
#        Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 69                         0.397750                0.000031
# 2518                       0.397750                0.000031
# 4730                       0.397750                0.000031
# 7179                       0.457169                0.000039
# 9549                       0.137646                0.000050
# 11998                      0.063154                0.000058
#
#        Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 69                     0.000007                0.000480
# 2518                   0.000007                0.000480
# 4730                   0.000007                0.000480
# 7179                   0.000010                0.000399
# 9549                   0.000013                0.000146
# 11998                  0.000007                0.000120
#
#        Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  \
# 69                     0.000359               0.000134
# 2518                   0.000359               0.000134
# 4730                   0.000359               0.000134
# 7179                   0.000411               0.000121
# 9549                   0.000028               0.000091
# 11998                  0.000031               0.000062
#
#        Rolling_Stddev_NO2_trop  Rolling_Mean_TropopausePressure  \
# 69                    0.000013                     16802.703337
# 2518                  0.000013                     16802.703337
# 4730                  0.000013                     16802.703337
# 7179                  0.000021                     18419.303213
# 9549                  0.000034                     19282.631057
# 11998                 0.000037                     18427.898923
#
#        Rolling_Stddev_TropopausePressure
# 69                           2423.189479
# 2518                         2423.189479
# 4730                         2423.189479
# 7179                         1495.877829
# 9549                            3.648099
# 11998                        1483.292120

# %%
grouped_v1_train=train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.groupby(['LAT','LON'])
grouped_v1_test=test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.groupby(['LAT','LON'])

# %%
#train
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['AAI_LAG3'] = grouped_v1_train['AAI'].shift(3)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LST_LAG1'] = grouped_v1_train['LST'].shift(1)

train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_strat_LAG1'] = grouped_v1_train['NO2_strat'].shift(1)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_strat_LAG2'] = grouped_v1_train['NO2_strat'].shift(2)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_strat_LAG3'] = grouped_v1_train['NO2_strat'].shift(3)

train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_total_LAG1'] = grouped_v1_train['NO2_total'].shift(1)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_total_LAG2'] = grouped_v1_train['NO2_total'].shift(2)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_total_LAG3'] = grouped_v1_train['NO2_total'].shift(3)

train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_trop_LAG1'] = grouped_v1_train['NO2_trop'].shift(1)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_trop_LAG2'] = grouped_v1_train['NO2_trop'].shift(2)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_trop_LAG3'] = grouped_v1_train['NO2_trop'].shift(3)

train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['TropopausePressure_LAG1'] = grouped_v1_train['TropopausePressure'].shift(1)
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['TropopausePressure_LAG2'] = grouped_v1_train['TropopausePressure'].shift(2)

#test
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['AAI_LAG3'] = grouped_v1_test['AAI'].shift(3)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LST_LAG1'] = grouped_v1_test['LST'].shift(1)

test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_strat_LAG1'] = grouped_v1_test['NO2_strat'].shift(1)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_strat_LAG2'] = grouped_v1_test['NO2_strat'].shift(2)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_strat_LAG3'] = grouped_v1_test['NO2_strat'].shift(3)

test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_total_LAG1'] = grouped_v1_test['NO2_total'].shift(1)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_total_LAG2'] = grouped_v1_test['NO2_total'].shift(2)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_total_LAG3'] = grouped_v1_test['NO2_total'].shift(3)

test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_trop_LAG1'] = grouped_v1_test['NO2_trop'].shift(1)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_trop_LAG2'] = grouped_v1_test['NO2_trop'].shift(2)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['NO2_trop_LAG3'] = grouped_v1_test['NO2_trop'].shift(3)

test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['TropopausePressure_LAG1'] = grouped_v1_test['TropopausePressure'].shift(1)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['TropopausePressure_LAG2'] = grouped_v1_test['TropopausePressure'].shift(2)

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==44.92469405].head(6)
# Out:
#              LAT        LON  Precipitation         LST       AAI  \
# 69     44.924694  10.517502       0.000000  280.675857  0.286079
# 2518   44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730   44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179   44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549   44.924694  10.517502       0.000000  303.260000 -0.987795
# 11998  44.924694  10.517502       0.000000  305.520000 -1.123626
#
#        CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69          0.954099   0.000024   0.000395  0.000140         14436.75358
# 2518        0.970421   0.000030   0.000873  0.000143         16692.01730
# 4730        0.273483   0.000037   0.000171  0.000119         19279.33913
# 7179        0.109390   0.000050   0.000152  0.000102         19286.55321
# 9549        0.000008   0.000063   0.000116  0.000053         19282.00083
# 11998       0.000000   0.000061   0.000091  0.000030         16715.14273
#
#             Date   ID_Zindi     PK  Rolling_Mean_Precipitation  \
# 69    2019-01-01  ID_ELHEMB     70                    2.737313
# 2518  2019-01-02  ID_RLD66Y   2519                    2.737313
# 4730  2019-01-03  ID_JLN5ZY   4731                    2.737313
# 7179  2019-01-04  ID_YC6QCK   7180                    2.737313
# 9549  2019-01-05  ID_I56YD1   9550                    0.000000
# 11998 2019-01-06  ID_FKZF1C  11999                    0.000000
#
#        Rolling_Stddev_Precipitation  Rolling_Mean_LST  Rolling_Stddev_LST  \
# 69                         4.741165        284.897063            8.112070
# 2518                       4.741165        284.897063            8.112070
# 4730                       4.741165        284.897063            8.112070
# 7179                       4.741165        289.418444            8.359263
# 9549                       0.000000        297.249778            5.205007
# 11998                      0.000000        301.006667            5.968059
#
#        Rolling_Mean_AAI  Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 69            -0.393219            0.607947                    0.732668
# 2518          -0.393219            0.607947                    0.732668
# 4730          -0.393219            0.607947                    0.732668
# 7179          -0.786601            0.179379                    0.451098
# 9549          -0.922692            0.056517                    0.127627
# 11998         -1.001830            0.115421                    0.036466
#
#        Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 69                         0.397750                0.000031
# 2518                       0.397750                0.000031
# 4730                       0.397750                0.000031
# 7179                       0.457169                0.000039
# 9549                       0.137646                0.000050
# 11998                      0.063154                0.000058
#
#        Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 69                     0.000007                0.000480
# 2518                   0.000007                0.000480
# 4730                   0.000007                0.000480
# 7179                   0.000010                0.000399
# 9549                   0.000013                0.000146
# 11998                  0.000007                0.000120
#
#        Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  \
# 69                     0.000359               0.000134
# 2518                   0.000359               0.000134
# 4730                   0.000359               0.000134
# 7179                   0.000411               0.000121
# 9549                   0.000028               0.000091
# 11998                  0.000031               0.000062
#
#        Rolling_Stddev_NO2_trop  Rolling_Mean_TropopausePressure  \
# 69                    0.000013                     16802.703337
# 2518                  0.000013                     16802.703337
# 4730                  0.000013                     16802.703337
# 7179                  0.000021                     18419.303213
# 9549                  0.000034                     19282.631057
# 11998                 0.000037                     18427.898923
#
#        Rolling_Stddev_TropopausePressure  AAI_LAG3    LST_LAG1  \
# 69                           2423.189479       NaN         NaN
# 2518                         2423.189479       NaN  280.675857
# 4730                         2423.189479       NaN  279.766000
# 7179                         1495.877829  0.286079  294.249333
# 9549                            3.648099 -0.579522  294.240000
# 11998                        1483.292120 -0.886214  303.260000
#
#        NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  NO2_total_LAG1  \
# 69                NaN             NaN             NaN             NaN
# 2518         0.000024             NaN             NaN        0.000395
# 4730         0.000030        0.000024             NaN        0.000873
# 7179         0.000037        0.000030        0.000024        0.000171
# 9549         0.000050        0.000037        0.000030        0.000152
# 11998        0.000063        0.000050        0.000037        0.000116
#
#        NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  NO2_trop_LAG2  \
# 69                NaN             NaN            NaN            NaN
# 2518              NaN             NaN       0.000140            NaN
# 4730         0.000395             NaN       0.000143       0.000140
# 7179         0.000873        0.000395       0.000119       0.000143
# 9549         0.000171        0.000873       0.000102       0.000119
# 11998        0.000152        0.000171       0.000053       0.000102
#
#        NO2_trop_LAG3  TropopausePressure_LAG1  TropopausePressure_LAG2
# 69               NaN                      NaN                      NaN
# 2518             NaN              14436.75358                      NaN
# 4730             NaN              16692.01730              14436.75358
# 7179        0.000140              19279.33913              16692.01730
# 9549        0.000143              19286.55321              19279.33913
# 11998       0.000119              19282.00083              19286.55321

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.head(6)
# Out:
#           LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 3   45.131947  10.015742       1.928031  279.369667  0.132952       0.756917
# 9   45.131947  10.015742       0.000000  279.369667 -0.626818       0.391763
# 15  45.131947  10.015742       0.000000  277.440000 -0.845165       0.000761
# 21  45.131947  10.015742       0.000000  279.066222 -1.342863       0.049850
# 27  45.131947  10.015742       1.928031  276.580000 -0.621298       0.061076
# 33  45.131947  10.015742       0.000000  279.380000 -0.634519       0.040908
#
#     NO2_strat  NO2_total  NO2_trop  TropopausePressure       Date   ID_Zindi  \
# 3    0.000024   0.000266  0.000114         14443.09006 2019-01-01  ID_QGSNTZ
# 9    0.000034   0.000223  0.000114         19330.30774 2019-01-02  ID_8JASJD
# 15   0.000030   0.000120  0.000090         22279.10381 2019-01-03  ID_C2YTPV
# 21   0.000020   0.000122  0.000102         16744.84559 2019-01-04  ID_O6FGA6
# 27   0.000018   0.000255  0.000193         16732.51469 2019-01-05  ID_ANJZBA
# 33   0.000022   0.000181  0.000172         16733.67227 2019-01-06  ID_ZOMAXE
#
#     PK  Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  \
# 3    4                    0.642677                      1.113149
# 9   10                    0.642677                      1.113149
# 15  16                    0.642677                      1.113149
# 21  22                    0.000000                      0.000000
# 27  28                    0.642677                      1.113149
# 33  34                    0.642677                      1.113149
#
#     Rolling_Mean_LST  Rolling_Stddev_LST  Rolling_Mean_AAI  \
# 3         278.726444            1.114094         -0.446344
# 9         278.726444            1.114094         -0.446344
# 15        278.726444            1.114094         -0.446344
# 21        278.625296            1.037649         -0.938282
# 27        277.695407            1.262636         -0.936442
# 33        278.342074            1.534045         -0.866226
#
#     Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 3             0.513426                    0.383147
# 9             0.513426                    0.383147
# 15            0.513426                    0.383147
# 21            0.366992                    0.147458
# 27            0.369341                    0.037229
# 33            0.412832                    0.050612
#
#     Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 3                       0.378152                0.000029
# 9                       0.378152                0.000029
# 15                      0.378152                0.000029
# 21                      0.212993                0.000028
# 27                      0.032077                0.000023
# 33                      0.010105                0.000020
#
#     Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 3                   0.000005                0.000203
# 9                   0.000005                0.000203
# 15                  0.000005                0.000203
# 21                  0.000007                0.000155
# 27                  0.000006                0.000166
# 33                  0.000002                0.000186
#
#     Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 3                   0.000075               0.000106                 0.000014
# 9                   0.000075               0.000106                 0.000014
# 15                  0.000075               0.000106                 0.000014
# 21                  0.000059               0.000102                 0.000012
# 27                  0.000077               0.000128                 0.000056
# 33                  0.000067               0.000156                 0.000048
#
#     Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 3                      18684.167203                        3957.764655
# 9                      18684.167203                        3957.764655
# 15                     18684.167203                        3957.764655
# 21                     19451.419047                        2769.116190
# 27                     18585.488030                        3198.771039
# 33                     16737.010850                           6.809725
#
#     AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 3        NaN         NaN             NaN             NaN             NaN
# 9        NaN  279.369667        0.000024             NaN             NaN
# 15       NaN  279.369667        0.000034        0.000024             NaN
# 21  0.132952  277.440000        0.000030        0.000034        0.000024
# 27 -0.626818  279.066222        0.000020        0.000030        0.000034
# 33 -0.845165  276.580000        0.000018        0.000020        0.000030
#
#     NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 3              NaN             NaN             NaN            NaN
# 9         0.000266             NaN             NaN       0.000114
# 15        0.000223        0.000266             NaN       0.000114
# 21        0.000120        0.000223        0.000266       0.000090
# 27        0.000122        0.000120        0.000223       0.000102
# 33        0.000255        0.000122        0.000120       0.000193
#
#     NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 3             NaN            NaN                      NaN
# 9             NaN            NaN              14443.09006
# 15       0.000114            NaN              19330.30774
# 21       0.000114       0.000114              22279.10381
# 27       0.000090       0.000114              16744.84559
# 33       0.000102       0.000090              16732.51469
#
#     TropopausePressure_LAG2
# 3                       NaN
# 9                       NaN
# 15              14443.09006
# 21              19330.30774
# 27              22279.10381
# 33              16744.84559

# %%
print(train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==44.92469405].shape[0])
print(test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==45.13194691].shape[0])
print(test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==45.28937609].shape[0])
# Out:
# 1096
# 1096
# 1096

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==45.13194691].head(5)
# Out:
#           LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 3   45.131947  10.015742       1.928031  279.369667  0.132952       0.756917
# 9   45.131947  10.015742       0.000000  279.369667 -0.626818       0.391763
# 15  45.131947  10.015742       0.000000  277.440000 -0.845165       0.000761
# 21  45.131947  10.015742       0.000000  279.066222 -1.342863       0.049850
# 27  45.131947  10.015742       1.928031  276.580000 -0.621298       0.061076
#
#     NO2_strat  NO2_total  NO2_trop  TropopausePressure       Date   ID_Zindi  \
# 3    0.000024   0.000266  0.000114         14443.09006 2019-01-01  ID_QGSNTZ
# 9    0.000034   0.000223  0.000114         19330.30774 2019-01-02  ID_8JASJD
# 15   0.000030   0.000120  0.000090         22279.10381 2019-01-03  ID_C2YTPV
# 21   0.000020   0.000122  0.000102         16744.84559 2019-01-04  ID_O6FGA6
# 27   0.000018   0.000255  0.000193         16732.51469 2019-01-05  ID_ANJZBA
#
#     PK  Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  \
# 3    4                    0.642677                      1.113149
# 9   10                    0.642677                      1.113149
# 15  16                    0.642677                      1.113149
# 21  22                    0.000000                      0.000000
# 27  28                    0.642677                      1.113149
#
#     Rolling_Mean_LST  Rolling_Stddev_LST  Rolling_Mean_AAI  \
# 3         278.726444            1.114094         -0.446344
# 9         278.726444            1.114094         -0.446344
# 15        278.726444            1.114094         -0.446344
# 21        278.625296            1.037649         -0.938282
# 27        277.695407            1.262636         -0.936442
#
#     Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 3             0.513426                    0.383147
# 9             0.513426                    0.383147
# 15            0.513426                    0.383147
# 21            0.366992                    0.147458
# 27            0.369341                    0.037229
#
#     Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 3                       0.378152                0.000029
# 9                       0.378152                0.000029
# 15                      0.378152                0.000029
# 21                      0.212993                0.000028
# 27                      0.032077                0.000023
#
#     Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 3                   0.000005                0.000203
# 9                   0.000005                0.000203
# 15                  0.000005                0.000203
# 21                  0.000007                0.000155
# 27                  0.000006                0.000166
#
#     Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 3                   0.000075               0.000106                 0.000014
# 9                   0.000075               0.000106                 0.000014
# 15                  0.000075               0.000106                 0.000014
# 21                  0.000059               0.000102                 0.000012
# 27                  0.000077               0.000128                 0.000056
#
#     Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 3                      18684.167203                        3957.764655
# 9                      18684.167203                        3957.764655
# 15                     18684.167203                        3957.764655
# 21                     19451.419047                        2769.116190
# 27                     18585.488030                        3198.771039
#
#     AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 3        NaN         NaN             NaN             NaN             NaN
# 9        NaN  279.369667        0.000024             NaN             NaN
# 15       NaN  279.369667        0.000034        0.000024             NaN
# 21  0.132952  277.440000        0.000030        0.000034        0.000024
# 27 -0.626818  279.066222        0.000020        0.000030        0.000034
#
#     NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 3              NaN             NaN             NaN            NaN
# 9         0.000266             NaN             NaN       0.000114
# 15        0.000223        0.000266             NaN       0.000114
# 21        0.000120        0.000223        0.000266       0.000090
# 27        0.000122        0.000120        0.000223       0.000102
#
#     NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 3             NaN            NaN                      NaN
# 9             NaN            NaN              14443.09006
# 15       0.000114            NaN              19330.30774
# 21       0.000114       0.000114              22279.10381
# 27       0.000090       0.000114              16744.84559
#
#     TropopausePressure_LAG2
# 3                       NaN
# 9                       NaN
# 15              14443.09006
# 21              19330.30774
# 27              22279.10381

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.head(5)
# Out:
#             LAT        LON  Precipitation         LST       AAI  \
# 69    44.924694  10.517502       0.000000  280.675857  0.286079
# 2518  44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730  44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179  44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549  44.924694  10.517502       0.000000  303.260000 -0.987795
#
#       CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69         0.954099   0.000024   0.000395  0.000140         14436.75358
# 2518       0.970421   0.000030   0.000873  0.000143         16692.01730
# 4730       0.273483   0.000037   0.000171  0.000119         19279.33913
# 7179       0.109390   0.000050   0.000152  0.000102         19286.55321
# 9549       0.000008   0.000063   0.000116  0.000053         19282.00083
#
#            Date   ID_Zindi    PK  Rolling_Mean_Precipitation  \
# 69   2019-01-01  ID_ELHEMB    70                    2.737313
# 2518 2019-01-02  ID_RLD66Y  2519                    2.737313
# 4730 2019-01-03  ID_JLN5ZY  4731                    2.737313
# 7179 2019-01-04  ID_YC6QCK  7180                    2.737313
# 9549 2019-01-05  ID_I56YD1  9550                    0.000000
#
#       Rolling_Stddev_Precipitation  Rolling_Mean_LST  Rolling_Stddev_LST  \
# 69                        4.741165        284.897063            8.112070
# 2518                      4.741165        284.897063            8.112070
# 4730                      4.741165        284.897063            8.112070
# 7179                      4.741165        289.418444            8.359263
# 9549                      0.000000        297.249778            5.205007
#
#       Rolling_Mean_AAI  Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 69           -0.393219            0.607947                    0.732668
# 2518         -0.393219            0.607947                    0.732668
# 4730         -0.393219            0.607947                    0.732668
# 7179         -0.786601            0.179379                    0.451098
# 9549         -0.922692            0.056517                    0.127627
#
#       Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 69                        0.397750                0.000031
# 2518                      0.397750                0.000031
# 4730                      0.397750                0.000031
# 7179                      0.457169                0.000039
# 9549                      0.137646                0.000050
#
#       Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 69                    0.000007                0.000480
# 2518                  0.000007                0.000480
# 4730                  0.000007                0.000480
# 7179                  0.000010                0.000399
# 9549                  0.000013                0.000146
#
#       Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  \
# 69                    0.000359               0.000134
# 2518                  0.000359               0.000134
# 4730                  0.000359               0.000134
# 7179                  0.000411               0.000121
# 9549                  0.000028               0.000091
#
#       Rolling_Stddev_NO2_trop  Rolling_Mean_TropopausePressure  \
# 69                   0.000013                     16802.703337
# 2518                 0.000013                     16802.703337
# 4730                 0.000013                     16802.703337
# 7179                 0.000021                     18419.303213
# 9549                 0.000034                     19282.631057
#
#       Rolling_Stddev_TropopausePressure  AAI_LAG3    LST_LAG1  NO2_strat_LAG1  \
# 69                          2423.189479       NaN         NaN             NaN
# 2518                        2423.189479       NaN  280.675857        0.000024
# 4730                        2423.189479       NaN  279.766000        0.000030
# 7179                        1495.877829  0.286079  294.249333        0.000037
# 9549                           3.648099 -0.579522  294.240000        0.000050
#
#       NO2_strat_LAG2  NO2_strat_LAG3  NO2_total_LAG1  NO2_total_LAG2  \
# 69               NaN             NaN             NaN             NaN
# 2518             NaN             NaN        0.000395             NaN
# 4730        0.000024             NaN        0.000873        0.000395
# 7179        0.000030        0.000024        0.000171        0.000873
# 9549        0.000037        0.000030        0.000152        0.000171
#
#       NO2_total_LAG3  NO2_trop_LAG1  NO2_trop_LAG2  NO2_trop_LAG3  \
# 69               NaN            NaN            NaN            NaN
# 2518             NaN       0.000140            NaN            NaN
# 4730             NaN       0.000143       0.000140            NaN
# 7179        0.000395       0.000119       0.000143       0.000140
# 9549        0.000873       0.000102       0.000119       0.000143
#
#       TropopausePressure_LAG1  TropopausePressure_LAG2
# 69                        NaN                      NaN
# 2518              14436.75358                      NaN
# 4730              16692.01730              14436.75358
# 7179              19279.33913              16692.01730
# 9549              19286.55321              19279.33913

# %%
LAG_Cols=[col for col in train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.columns if "LAG" in col]
LAG_Cols
# Out:
# ['AAI_LAG3',
#  'LST_LAG1',
#  'NO2_strat_LAG1',
#  'NO2_strat_LAG2',
#  'NO2_strat_LAG3',
#  'NO2_total_LAG1',
#  'NO2_total_LAG2',
#  'NO2_total_LAG3',
#  'NO2_trop_LAG1',
#  'NO2_trop_LAG2',
#  'NO2_trop_LAG3',
#  'TropopausePressure_LAG1',
#  'TropopausePressure_LAG2']

# %%
#Doing backfill 
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.fillna(method='bfill', inplace=True)
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.fillna(method='bfill', inplace=True)

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==44.92469405].head(6)
# Out:
#              LAT        LON  Precipitation         LST       AAI  \
# 69     44.924694  10.517502       0.000000  280.675857  0.286079
# 2518   44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730   44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179   44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549   44.924694  10.517502       0.000000  303.260000 -0.987795
# 11998  44.924694  10.517502       0.000000  305.520000 -1.123626
#
#        CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69          0.954099   0.000024   0.000395  0.000140         14436.75358
# 2518        0.970421   0.000030   0.000873  0.000143         16692.01730
# 4730        0.273483   0.000037   0.000171  0.000119         19279.33913
# 7179        0.109390   0.000050   0.000152  0.000102         19286.55321
# 9549        0.000008   0.000063   0.000116  0.000053         19282.00083
# 11998       0.000000   0.000061   0.000091  0.000030         16715.14273
#
#             Date   ID_Zindi     PK  Rolling_Mean_Precipitation  \
# 69    2019-01-01  ID_ELHEMB     70                    2.737313
# 2518  2019-01-02  ID_RLD66Y   2519                    2.737313
# 4730  2019-01-03  ID_JLN5ZY   4731                    2.737313
# 7179  2019-01-04  ID_YC6QCK   7180                    2.737313
# 9549  2019-01-05  ID_I56YD1   9550                    0.000000
# 11998 2019-01-06  ID_FKZF1C  11999                    0.000000
#
#        Rolling_Stddev_Precipitation  Rolling_Mean_LST  Rolling_Stddev_LST  \
# 69                         4.741165        284.897063            8.112070
# 2518                       4.741165        284.897063            8.112070
# 4730                       4.741165        284.897063            8.112070
# 7179                       4.741165        289.418444            8.359263
# 9549                       0.000000        297.249778            5.205007
# 11998                      0.000000        301.006667            5.968059
#
#        Rolling_Mean_AAI  Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 69            -0.393219            0.607947                    0.732668
# 2518          -0.393219            0.607947                    0.732668
# 4730          -0.393219            0.607947                    0.732668
# 7179          -0.786601            0.179379                    0.451098
# 9549          -0.922692            0.056517                    0.127627
# 11998         -1.001830            0.115421                    0.036466
#
#        Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 69                         0.397750                0.000031
# 2518                       0.397750                0.000031
# 4730                       0.397750                0.000031
# 7179                       0.457169                0.000039
# 9549                       0.137646                0.000050
# 11998                      0.063154                0.000058
#
#        Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 69                     0.000007                0.000480
# 2518                   0.000007                0.000480
# 4730                   0.000007                0.000480
# 7179                   0.000010                0.000399
# 9549                   0.000013                0.000146
# 11998                  0.000007                0.000120
#
#        Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  \
# 69                     0.000359               0.000134
# 2518                   0.000359               0.000134
# 4730                   0.000359               0.000134
# 7179                   0.000411               0.000121
# 9549                   0.000028               0.000091
# 11998                  0.000031               0.000062
#
#        Rolling_Stddev_NO2_trop  Rolling_Mean_TropopausePressure  \
# 69                    0.000013                     16802.703337
# 2518                  0.000013                     16802.703337
# 4730                  0.000013                     16802.703337
# 7179                  0.000021                     18419.303213
# 9549                  0.000034                     19282.631057
# 11998                 0.000037                     18427.898923
#
#        Rolling_Stddev_TropopausePressure  AAI_LAG3    LST_LAG1  \
# 69                           2423.189479  0.286079  280.675857
# 2518                         2423.189479  0.286079  280.675857
# 4730                         2423.189479  0.286079  279.766000
# 7179                         1495.877829  0.286079  294.249333
# 9549                            3.648099 -0.579522  294.240000
# 11998                        1483.292120 -0.886214  303.260000
#
#        NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  NO2_total_LAG1  \
# 69           0.000024        0.000024        0.000024        0.000395
# 2518         0.000024        0.000024        0.000024        0.000395
# 4730         0.000030        0.000024        0.000024        0.000873
# 7179         0.000037        0.000030        0.000024        0.000171
# 9549         0.000050        0.000037        0.000030        0.000152
# 11998        0.000063        0.000050        0.000037        0.000116
#
#        NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  NO2_trop_LAG2  \
# 69           0.000395        0.000395       0.000140       0.000140
# 2518         0.000395        0.000395       0.000140       0.000140
# 4730         0.000395        0.000395       0.000143       0.000140
# 7179         0.000873        0.000395       0.000119       0.000143
# 9549         0.000171        0.000873       0.000102       0.000119
# 11998        0.000152        0.000171       0.000053       0.000102
#
#        NO2_trop_LAG3  TropopausePressure_LAG1  TropopausePressure_LAG2
# 69          0.000140              14436.75358              14436.75358
# 2518        0.000140              14436.75358              14436.75358
# 4730        0.000140              16692.01730              14436.75358
# 7179        0.000140              19279.33913              16692.01730
# 9549        0.000143              19286.55321              19279.33913
# 11998       0.000119              19282.00083              19286.55321

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1[test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1['LAT']==45.13194691].head(5)
# Out:
#           LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 3   45.131947  10.015742       1.928031  279.369667  0.132952       0.756917
# 9   45.131947  10.015742       0.000000  279.369667 -0.626818       0.391763
# 15  45.131947  10.015742       0.000000  277.440000 -0.845165       0.000761
# 21  45.131947  10.015742       0.000000  279.066222 -1.342863       0.049850
# 27  45.131947  10.015742       1.928031  276.580000 -0.621298       0.061076
#
#     NO2_strat  NO2_total  NO2_trop  TropopausePressure       Date   ID_Zindi  \
# 3    0.000024   0.000266  0.000114         14443.09006 2019-01-01  ID_QGSNTZ
# 9    0.000034   0.000223  0.000114         19330.30774 2019-01-02  ID_8JASJD
# 15   0.000030   0.000120  0.000090         22279.10381 2019-01-03  ID_C2YTPV
# 21   0.000020   0.000122  0.000102         16744.84559 2019-01-04  ID_O6FGA6
# 27   0.000018   0.000255  0.000193         16732.51469 2019-01-05  ID_ANJZBA
#
#     PK  Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  \
# 3    4                    0.642677                      1.113149
# 9   10                    0.642677                      1.113149
# 15  16                    0.642677                      1.113149
# 21  22                    0.000000                      0.000000
# 27  28                    0.642677                      1.113149
#
#     Rolling_Mean_LST  Rolling_Stddev_LST  Rolling_Mean_AAI  \
# 3         278.726444            1.114094         -0.446344
# 9         278.726444            1.114094         -0.446344
# 15        278.726444            1.114094         -0.446344
# 21        278.625296            1.037649         -0.938282
# 27        277.695407            1.262636         -0.936442
#
#     Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 3             0.513426                    0.383147
# 9             0.513426                    0.383147
# 15            0.513426                    0.383147
# 21            0.366992                    0.147458
# 27            0.369341                    0.037229
#
#     Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 3                       0.378152                0.000029
# 9                       0.378152                0.000029
# 15                      0.378152                0.000029
# 21                      0.212993                0.000028
# 27                      0.032077                0.000023
#
#     Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 3                   0.000005                0.000203
# 9                   0.000005                0.000203
# 15                  0.000005                0.000203
# 21                  0.000007                0.000155
# 27                  0.000006                0.000166
#
#     Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 3                   0.000075               0.000106                 0.000014
# 9                   0.000075               0.000106                 0.000014
# 15                  0.000075               0.000106                 0.000014
# 21                  0.000059               0.000102                 0.000012
# 27                  0.000077               0.000128                 0.000056
#
#     Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 3                      18684.167203                        3957.764655
# 9                      18684.167203                        3957.764655
# 15                     18684.167203                        3957.764655
# 21                     19451.419047                        2769.116190
# 27                     18585.488030                        3198.771039
#
#     AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 3   0.132952  279.369667        0.000024        0.000024        0.000024
# 9   0.132952  279.369667        0.000024        0.000024        0.000024
# 15  0.132952  279.369667        0.000034        0.000024        0.000024
# 21  0.132952  277.440000        0.000030        0.000034        0.000024
# 27 -0.626818  279.066222        0.000020        0.000030        0.000034
#
#     NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 3         0.000266        0.000266        0.000266       0.000114
# 9         0.000266        0.000266        0.000266       0.000114
# 15        0.000223        0.000266        0.000266       0.000114
# 21        0.000120        0.000223        0.000266       0.000090
# 27        0.000122        0.000120        0.000223       0.000102
#
#     NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 3        0.000114       0.000114              14443.09006
# 9        0.000114       0.000114              14443.09006
# 15       0.000114       0.000114              19330.30774
# 21       0.000114       0.000114              22279.10381
# 27       0.000090       0.000114              16744.84559
#
#     TropopausePressure_LAG2
# 3               14443.09006
# 9               14443.09006
# 15              14443.09006
# 21              19330.30774
# 27              22279.10381

# %%
#Checking if any null present or not
print('train null check\n',train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.isnull().sum())
print('\n')
print('test null check\n',test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.isnull().sum())
# Out:
# train null check
#  LAT                                  0
# LON                                  0
# Precipitation                        0
# LST                                  0
# AAI                                  0
# CloudFraction                        0
# NO2_strat                            0
# NO2_total                            0
# NO2_trop                             0
# TropopausePressure                   0
# Date                                 0
# ID_Zindi                             0
# PK                                   0
# Rolling_Mean_Precipitation           0
# Rolling_Stddev_Precipitation         0
# Rolling_Mean_LST                     0
# Rolling_Stddev_LST                   0
# Rolling_Mean_AAI                     0
# Rolling_Stddev_AAI                   0
# Rolling_Mean_CloudFraction           0
# Rolling_Stddev_CloudFraction         0
# Rolling_Mean_NO2_strat               0
# Rolling_Stddev_NO2_strat             0
# Rolling_Mean_NO2_total               0
# Rolling_Stddev_NO2_total             0
# Rolling_Mean_NO2_trop                0
# Rolling_Stddev_NO2_trop              0
# Rolling_Mean_TropopausePressure      0
# Rolling_Stddev_TropopausePressure    0
# AAI_LAG3                             0
# LST_LAG1                             0
# NO2_strat_LAG1                       0
# NO2_strat_LAG2                       0
# NO2_strat_LAG3                       0
# NO2_total_LAG1                       0
# NO2_total_LAG2                       0
# NO2_total_LAG3                       0
# NO2_trop_LAG1                        0
# NO2_trop_LAG2                        0
# NO2_trop_LAG3                        0
# TropopausePressure_LAG1              0
# TropopausePressure_LAG2              0
# dtype: int64
#
#
# test null check
#  LAT                                  0
# LON                                  0
# Precipitation                        0
# LST                                  0
# AAI                                  0
# CloudFraction                        0
# NO2_strat                            0
# NO2_total                            0
# NO2_trop                             0
# TropopausePressure                   0
# Date                                 0
# ID_Zindi                             0
# PK                                   0
# Rolling_Mean_Precipitation           0
# Rolling_Stddev_Precipitation         0
# Rolling_Mean_LST                     0
# Rolling_Stddev_LST                   0
# Rolling_Mean_AAI                     0
# Rolling_Stddev_AAI                   0
# Rolling_Mean_CloudFraction           0
# Rolling_Stddev_CloudFraction         0
# Rolling_Mean_NO2_strat               0
# Rolling_Stddev_NO2_strat             0
# Rolling_Mean_NO2_total               0
# Rolling_Stddev_NO2_total             0
# Rolling_Mean_NO2_trop                0
# Rolling_Stddev_NO2_trop              0
# Rolling_Mean_TropopausePressure      0
# Rolling_Stddev_TropopausePressure    0
# AAI_LAG3                             0
# LST_LAG1                             0
# NO2_strat_LAG1                       0
# NO2_strat_LAG2                       0
# NO2_strat_LAG3                       0
# NO2_total_LAG1                       0
# NO2_total_LAG2                       0
# NO2_total_LAG3                       0
# NO2_trop_LAG1                        0
# NO2_trop_LAG2                        0
# NO2_trop_LAG3                        0
# TropopausePressure_LAG1              0
# TropopausePressure_LAG2              0
# dtype: int64

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.head(5)
# Out:
#             LAT        LON  Precipitation         LST       AAI  \
# 69    44.924694  10.517502       0.000000  280.675857  0.286079
# 2518  44.924694  10.517502       8.211939  279.766000 -0.579522
# 4730  44.924694  10.517502       0.000000  294.249333 -0.886214
# 7179  44.924694  10.517502       0.000000  294.240000 -0.894068
# 9549  44.924694  10.517502       0.000000  303.260000 -0.987795
#
#       CloudFraction  NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 69         0.954099   0.000024   0.000395  0.000140         14436.75358
# 2518       0.970421   0.000030   0.000873  0.000143         16692.01730
# 4730       0.273483   0.000037   0.000171  0.000119         19279.33913
# 7179       0.109390   0.000050   0.000152  0.000102         19286.55321
# 9549       0.000008   0.000063   0.000116  0.000053         19282.00083
#
#            Date   ID_Zindi    PK  Rolling_Mean_Precipitation  \
# 69   2019-01-01  ID_ELHEMB    70                    2.737313
# 2518 2019-01-02  ID_RLD66Y  2519                    2.737313
# 4730 2019-01-03  ID_JLN5ZY  4731                    2.737313
# 7179 2019-01-04  ID_YC6QCK  7180                    2.737313
# 9549 2019-01-05  ID_I56YD1  9550                    0.000000
#
#       Rolling_Stddev_Precipitation  Rolling_Mean_LST  Rolling_Stddev_LST  \
# 69                        4.741165        284.897063            8.112070
# 2518                      4.741165        284.897063            8.112070
# 4730                      4.741165        284.897063            8.112070
# 7179                      4.741165        289.418444            8.359263
# 9549                      0.000000        297.249778            5.205007
#
#       Rolling_Mean_AAI  Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 69           -0.393219            0.607947                    0.732668
# 2518         -0.393219            0.607947                    0.732668
# 4730         -0.393219            0.607947                    0.732668
# 7179         -0.786601            0.179379                    0.451098
# 9549         -0.922692            0.056517                    0.127627
#
#       Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 69                        0.397750                0.000031
# 2518                      0.397750                0.000031
# 4730                      0.397750                0.000031
# 7179                      0.457169                0.000039
# 9549                      0.137646                0.000050
#
#       Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 69                    0.000007                0.000480
# 2518                  0.000007                0.000480
# 4730                  0.000007                0.000480
# 7179                  0.000010                0.000399
# 9549                  0.000013                0.000146
#
#       Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  \
# 69                    0.000359               0.000134
# 2518                  0.000359               0.000134
# 4730                  0.000359               0.000134
# 7179                  0.000411               0.000121
# 9549                  0.000028               0.000091
#
#       Rolling_Stddev_NO2_trop  Rolling_Mean_TropopausePressure  \
# 69                   0.000013                     16802.703337
# 2518                 0.000013                     16802.703337
# 4730                 0.000013                     16802.703337
# 7179                 0.000021                     18419.303213
# 9549                 0.000034                     19282.631057
#
#       Rolling_Stddev_TropopausePressure  AAI_LAG3    LST_LAG1  NO2_strat_LAG1  \
# 69                          2423.189479  0.286079  280.675857        0.000024
# 2518                        2423.189479  0.286079  280.675857        0.000024
# 4730                        2423.189479  0.286079  279.766000        0.000030
# 7179                        1495.877829  0.286079  294.249333        0.000037
# 9549                           3.648099 -0.579522  294.240000        0.000050
#
#       NO2_strat_LAG2  NO2_strat_LAG3  NO2_total_LAG1  NO2_total_LAG2  \
# 69          0.000024        0.000024        0.000395        0.000395
# 2518        0.000024        0.000024        0.000395        0.000395
# 4730        0.000024        0.000024        0.000873        0.000395
# 7179        0.000030        0.000024        0.000171        0.000873
# 9549        0.000037        0.000030        0.000152        0.000171
#
#       NO2_total_LAG3  NO2_trop_LAG1  NO2_trop_LAG2  NO2_trop_LAG3  \
# 69          0.000395       0.000140       0.000140       0.000140
# 2518        0.000395       0.000140       0.000140       0.000140
# 4730        0.000395       0.000143       0.000140       0.000140
# 7179        0.000395       0.000119       0.000143       0.000140
# 9549        0.000873       0.000102       0.000119       0.000143
#
#       TropopausePressure_LAG1  TropopausePressure_LAG2
# 69                14436.75358              14436.75358
# 2518              14436.75358              14436.75358
# 4730              16692.01730              14436.75358
# 7179              19279.33913              16692.01730
# 9549              19286.55321              19279.33913

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1 = train_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.sort_values(by='PK')
test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1 = test_model3_df_prep_mix_roll_wind_mean_stddev_sorted_v1.sort_values(by='PK')
train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1=train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.drop(['ID_Zindi','PK','Date'],axis=1)
test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1=test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.drop(['ID_Zindi','PK','Date'],axis=1)

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.head(5)
# Out:
#          LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 0  45.601585  11.903551       0.000000  280.097333  0.230527       0.559117
# 1  45.371005  11.840830       3.047342  280.097333 -0.074006       0.869309
# 2  45.045825  12.060869       0.000000  280.097333  0.024470       0.674160
# 3  45.104075  11.553241       1.200467  280.097333 -0.010442       0.920054
# 4  45.038758  11.790152       1.274564  280.097333 -0.176178       0.747464
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0   0.000024   0.000117  0.000131         14440.82126
# 1   0.000024   0.000127  0.000131         14441.79815
# 2   0.000024   0.000086  0.000131         14437.38294
# 3   0.000024   0.000124  0.000131         14440.83831
# 4   0.000024   0.000116  0.000131         14438.79037
#
#    Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  Rolling_Mean_LST  \
# 0                    6.584876                     11.405339        283.669317
# 1                    5.571793                      7.175196        283.636820
# 2                    3.979073                      6.891956        283.587963
# 3                    2.328808                      3.053554        283.516375
# 4                    4.241536                      6.275195        283.483280
#
#    Rolling_Stddev_LST  Rolling_Mean_AAI  Rolling_Stddev_AAI  \
# 0            7.679005         -0.287823            0.483869
# 1            7.758017         -0.426385            0.316991
# 2            7.833510         -0.345919            0.343860
# 3            7.892164         -0.159093            0.268755
# 4            7.998216         -0.357413            0.178524
#
#    Rolling_Mean_CloudFraction  Rolling_Stddev_CloudFraction  \
# 0                    0.719599                      0.139724
# 1                    0.757004                      0.141170
# 2                    0.768430                      0.081828
# 3                    0.856576                      0.183586
# 4                    0.774600                      0.097796
#
#    Rolling_Mean_NO2_strat  Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0                0.000032                  0.000007                0.000183
# 1                0.000032                  0.000007                0.000214
# 2                0.000033                  0.000008                0.000172
# 3                0.000031                  0.000007                0.000304
# 4                0.000033                  0.000008                0.000207
#
#    Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                  0.000121               0.000161                 0.000041
# 1                  0.000104               0.000159                 0.000040
# 2                  0.000135               0.000158                 0.000038
# 3                  0.000281               0.000156                 0.000034
# 4                  0.000129               0.000155                 0.000031
#
#    Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                     17478.750221                        2648.341256
# 1                     17419.601916                        2609.250967
# 2                     17350.081865                        2567.367039
# 3                     16813.639260                        2431.513770
# 4                     17231.772274                        2508.138542
#
#    AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0  0.230527  280.097333        0.000024        0.000024        0.000024
# 1 -0.074006  280.097333        0.000024        0.000024        0.000024
# 2  0.024470  280.097333        0.000024        0.000024        0.000024
# 3 -0.010442  280.097333        0.000024        0.000024        0.000024
# 4 -0.176178  280.097333        0.000024        0.000024        0.000024
#
#    NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0        0.000117        0.000117        0.000117       0.000131
# 1        0.000127        0.000127        0.000127       0.000131
# 2        0.000086        0.000086        0.000086       0.000131
# 3        0.000124        0.000124        0.000124       0.000131
# 4        0.000116        0.000116        0.000116       0.000131
#
#    NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0       0.000131       0.000131              14440.82126
# 1       0.000131       0.000131              14441.79815
# 2       0.000131       0.000131              14437.38294
# 3       0.000131       0.000131              14440.83831
# 4       0.000131       0.000131              14438.79037
#
#    TropopausePressure_LAG2
# 0              14440.82126
# 1              14441.79815
# 2              14437.38294
# 3              14440.83831
# 4              14438.79037

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.head(5)
# Out:
#          LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 0  45.289376  11.642394       3.277529  279.369667 -0.313361       0.771456
# 1  45.836941  12.510362       0.000000  279.369667 -0.229512       0.398208
# 2  45.582894   8.842165       0.000000  282.980000 -0.470822       0.153694
# 3  45.131947  10.015742       1.928031  279.369667  0.132952       0.756917
# 4  45.186329   9.146666       0.000000  279.369667 -0.198272       0.678858
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0   0.000024   0.000075  0.000114         14440.02819
# 1   0.000023   0.000120  0.000114         14434.04790
# 2   0.000023   0.000171  0.000148         14427.42478
# 3   0.000024   0.000266  0.000114         14443.09006
# 4   0.000023   0.000149  0.000114         14440.85840
#
#    Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  Rolling_Mean_LST  \
# 0                    1.092510                      1.892282        278.209889
# 1                    0.000000                      0.000000        280.769889
# 2                    0.000000                      0.000000        282.366667
# 3                    0.642677                      1.113149        278.726444
# 4                    0.000000                      0.000000        280.842222
#
#    Rolling_Stddev_LST  Rolling_Mean_AAI  Rolling_Stddev_AAI  \
# 0            3.593232         -0.402533            0.280688
# 1            1.504183         -0.528932            0.269267
# 2            1.629028         -0.679175            0.183454
# 3            1.114094         -0.446344            0.513426
# 4            2.631201         -0.774266            0.583420
#
#    Rolling_Mean_CloudFraction  Rolling_Stddev_CloudFraction  \
# 0                    0.312794                      0.405887
# 1                    0.148067                      0.217846
# 2                    0.051231                      0.088735
# 3                    0.383147                      0.378152
# 4                    0.333002                      0.339611
#
#    Rolling_Mean_NO2_strat  Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0                0.000029                  0.000005                0.000089
# 1                0.000028                  0.000004                0.000105
# 2                0.000028                  0.000005                0.000170
# 3                0.000029                  0.000005                0.000203
# 4                0.000029                  0.000005                0.000116
#
#    Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                  0.000034               0.000069                 0.000041
# 1                  0.000036               0.000084                 0.000045
# 2                  0.000096               0.000143                 0.000098
# 3                  0.000075               0.000106                 0.000014
# 4                  0.000034               0.000092                 0.000039
#
#    Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                     19153.006053                        4147.001140
# 1                     19131.785407                        4135.206982
# 2                     18626.888577                        3916.558243
# 3                     18684.167203                        3957.764655
# 4                     18673.041120                        3949.256780
#
#    AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0 -0.313361  279.369667        0.000024        0.000024        0.000024
# 1 -0.229512  279.369667        0.000023        0.000023        0.000023
# 2 -0.470822  282.980000        0.000023        0.000023        0.000023
# 3  0.132952  279.369667        0.000024        0.000024        0.000024
# 4 -0.198272  279.369667        0.000023        0.000023        0.000023
#
#    NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0        0.000075        0.000075        0.000075       0.000114
# 1        0.000120        0.000120        0.000120       0.000114
# 2        0.000171        0.000171        0.000171       0.000148
# 3        0.000266        0.000266        0.000266       0.000114
# 4        0.000149        0.000149        0.000149       0.000114
#
#    NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0       0.000114       0.000114              14440.02819
# 1       0.000114       0.000114              14434.04790
# 2       0.000148       0.000148              14427.42478
# 3       0.000114       0.000114              14443.09006
# 4       0.000114       0.000114              14440.85840
#
#    TropopausePressure_LAG2
# 0              14440.02819
# 1              14434.04790
# 2              14427.42478
# 3              14443.09006
# 4              14440.85840

# %%
print(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[abs(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew())>0.5])
Skewed_cols=train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[abs(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew())>0.5].index.to_list()

print(Skewed_cols)
# Out:
# LON                                  0.911077
# Precipitation                        4.569618
# CloudFraction                        1.236881
# NO2_total                            4.169193
# NO2_trop                             2.935214
# Rolling_Mean_Precipitation           2.702031
# Rolling_Stddev_Precipitation         2.793419
# Rolling_Stddev_LST                   1.407023
# Rolling_Mean_AAI                     0.558595
# Rolling_Stddev_AAI                   1.204749
# Rolling_Mean_CloudFraction           0.824397
# Rolling_Stddev_CloudFraction         0.507065
# Rolling_Stddev_NO2_strat             1.383593
# Rolling_Mean_NO2_total               2.855243
# Rolling_Stddev_NO2_total             4.382217
# Rolling_Mean_NO2_trop                2.107716
# Rolling_Stddev_NO2_trop              2.970711
# Rolling_Stddev_TropopausePressure    0.806626
# NO2_total_LAG1                       4.179662
# NO2_total_LAG2                       4.183827
# NO2_total_LAG3                       4.180559
# NO2_trop_LAG1                        2.937295
# NO2_trop_LAG2                        2.937191
# NO2_trop_LAG3                        2.934675
# dtype: float64
# ['LON', 'Precipitation', 'CloudFraction', 'NO2_total', 'NO2_trop', 'Rolling_Mean_Precipitation', 'Rolling_Stddev_Precipitation', 'Rolling_Stddev_LST', 'Rolling_Mean_AAI', 'Rolling_Stddev_AAI', 'Rolling_Mean_CloudFraction', 'Rolling_Stddev_CloudFraction', 'Rolling_Stddev_NO2_strat', 'Rolling_Mean_NO2_total', 'Rolling_Stddev_NO2_total', 'Rolling_Mean_NO2_trop', 'Rolling_Stddev_NO2_trop', 'Rolling_Stddev_TropopausePressure', 'NO2_total_LAG1', 'NO2_total_LAG2', 'NO2_total_LAG3', 'NO2_trop_LAG1', 'NO2_trop_LAG2', 'NO2_trop_LAG3']

# %%
print(test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[abs(test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew())>0.5])
# Out:
# LAT                                  0.839399
# Precipitation                        4.409900
# AAI                                  0.557857
# CloudFraction                        1.295619
# NO2_total                            5.237289
# NO2_trop                             3.275638
# Rolling_Mean_Precipitation           2.613215
# Rolling_Stddev_Precipitation         2.756800
# Rolling_Stddev_LST                   2.293982
# Rolling_Mean_AAI                     0.667658
# Rolling_Stddev_AAI                   1.358639
# Rolling_Mean_CloudFraction           0.978377
# Rolling_Stddev_CloudFraction         0.884107
# Rolling_Stddev_NO2_strat             1.327646
# Rolling_Mean_NO2_total               4.225154
# Rolling_Stddev_NO2_total             5.097974
# Rolling_Mean_NO2_trop                1.971349
# Rolling_Stddev_NO2_trop              4.451370
# Rolling_Stddev_TropopausePressure    0.806643
# AAI_LAG3                             0.555439
# NO2_total_LAG1                       5.250821
# NO2_total_LAG2                       5.259539
# NO2_total_LAG3                       5.256696
# NO2_trop_LAG1                        3.276598
# NO2_trop_LAG2                        3.262121
# NO2_trop_LAG3                        3.262188
# dtype: float64

# %%
#Before treating for skewness lets create a model

model= LinearRegression()
model.fit(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1, train_model3_df_prep_mix_GT_NO2_mix)

# Predict using the test dataset
y_pred = model.predict(test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1)

# Add additional 'ID_Zindi' to y_pred3 and create a DataFrame
y_pred_df = pd.DataFrame(y_pred, columns=['GT_NO2'])
y_pred_result_df = pd.concat([test_df['ID_Zindi'], y_pred_df], axis=1)

# Save the results to a CSV file
y_pred_result_df.to_csv('/home/anuragverma/Desktop/Kaggle/GeoAI Ground-level NO2 _Zindi/model5_lag_roll.csv', index=False)

# %%
print(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[abs(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew())>0.5])
Skewed_cols=train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[abs(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew())>0.5].index.to_list()
print(Skewed_cols)
Skewed_cols.remove('LON')
# Out:
# LON                                  0.911077
# Precipitation                        4.569618
# CloudFraction                        1.236881
# NO2_total                            4.169193
# NO2_trop                             2.935214
# Rolling_Mean_Precipitation           2.702031
# Rolling_Stddev_Precipitation         2.793419
# Rolling_Stddev_LST                   1.407023
# Rolling_Mean_AAI                     0.558595
# Rolling_Stddev_AAI                   1.204749
# Rolling_Mean_CloudFraction           0.824397
# Rolling_Stddev_CloudFraction         0.507065
# Rolling_Stddev_NO2_strat             1.383593
# Rolling_Mean_NO2_total               2.855243
# Rolling_Stddev_NO2_total             4.382217
# Rolling_Mean_NO2_trop                2.107716
# Rolling_Stddev_NO2_trop              2.970711
# Rolling_Stddev_TropopausePressure    0.806626
# NO2_total_LAG1                       4.179662
# NO2_total_LAG2                       4.183827
# NO2_total_LAG3                       4.180559
# NO2_trop_LAG1                        2.937295
# NO2_trop_LAG2                        2.937191
# NO2_trop_LAG3                        2.934675
# dtype: float64
# ['LON', 'Precipitation', 'CloudFraction', 'NO2_total', 'NO2_trop', 'Rolling_Mean_Precipitation', 'Rolling_Stddev_Precipitation', 'Rolling_Stddev_LST', 'Rolling_Mean_AAI', 'Rolling_Stddev_AAI', 'Rolling_Mean_CloudFraction', 'Rolling_Stddev_CloudFraction', 'Rolling_Stddev_NO2_strat', 'Rolling_Mean_NO2_total', 'Rolling_Stddev_NO2_total', 'Rolling_Mean_NO2_trop', 'Rolling_Stddev_NO2_trop', 'Rolling_Stddev_TropopausePressure', 'NO2_total_LAG1', 'NO2_total_LAG2', 'NO2_total_LAG3', 'NO2_trop_LAG1', 'NO2_trop_LAG2', 'NO2_trop_LAG3']

# %%
#Treating skewness with log
def log_transfrom_trt(series):
    if series.min()<0:
        offset=abs(series.min())+0.0001
    else:
        offset=0.0001
    return np.log(series+offset)

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1=train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.copy()
train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.head(20)
# Out:
#           LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 0   45.601585  11.903551       0.000000  280.097333  0.230527       0.559117
# 1   45.371005  11.840830       3.047342  280.097333 -0.074006       0.869309
# 2   45.045825  12.060869       0.000000  280.097333  0.024470       0.674160
# 3   45.104075  11.553241       1.200467  280.097333 -0.010442       0.920054
# 4   45.038758  11.790152       1.274564  280.097333 -0.176178       0.747464
# 5   45.889734  12.307124       0.000000  278.380000 -0.366831       0.324392
# 6   45.671721  12.237807       0.000000  280.097333  0.188599       0.818422
# 7   45.629092  12.590682       0.000000  280.097333  0.507837       0.926018
# 8   45.499618  12.261249       0.000000  280.097333  0.087363       0.835097
# 9   45.428424  12.312930       0.650355  280.097333  0.208678       0.812696
# 10  45.759273  11.735852       0.000000  280.097333 -0.633875       0.171895
# 11  45.713559  11.367657       0.000000  275.180000 -0.159398       0.000000
# 12  45.559561  11.538654       0.000000  280.097333 -0.204458       0.275040
# 13  45.182626  11.310511       6.699392  280.097333  0.051284       0.884321
# 14  45.433405  11.030569       4.588969  280.097333 -0.110994       0.776272
# 15  45.690429   9.484261       0.000000  281.480000 -0.531419       0.140807
# 16  45.619244   8.756970       0.000000  282.980000 -0.580316       0.121120
# 17  45.412772  10.683357       1.800207  280.360889 -0.352985       0.622817
# 18  45.046502  11.180936       2.929149  280.464333 -0.002400       0.881816
# 19  45.016878  11.076095       2.950671  280.571167  0.121945       0.955316
#
#     NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0    0.000024   0.000117  0.000131         14440.82126
# 1    0.000024   0.000127  0.000131         14441.79815
# 2    0.000024   0.000086  0.000131         14437.38294
# 3    0.000024   0.000124  0.000131         14440.83831
# 4    0.000024   0.000116  0.000131         14438.79037
# 5    0.000023   0.000109  0.000131         14432.05624
# 6    0.000024   0.000135  0.000131         14436.70176
# 7    0.000024   0.000137  0.000131         14435.01960
# 8    0.000024   0.000104  0.000131         14438.51425
# 9    0.000024   0.000117  0.000131         14437.71015
# 10   0.000024   0.000079  0.000131         14431.63877
# 11   0.000024   0.000101  0.000084         14422.64906
# 12   0.000024   0.000122  0.000131         14443.86329
# 13   0.000024   0.000146  0.000131         14442.95417
# 14   0.000024   0.000145  0.000131         14442.46222
# 15   0.000023   0.000245  0.000288         14429.31480
# 16   0.000023   0.000156  0.000133         14425.69705
# 17   0.000024   0.000171  0.000136         14442.65422
# 18   0.000024   0.000268  0.000140         14440.19880
# 19   0.000024   0.000360  0.000144         14438.88636
#
#     Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  \
# 0                     6.584876                     11.405339
# 1                     5.571793                      7.175196
# 2                     3.979073                      6.891956
# 3                     2.328808                      3.053554
# 4                     4.241536                      6.275195
# 5                     6.467497                      6.946312
# 6                     8.585276                     10.632579
# 7                     5.563950                      9.637044
# 8                     5.121933                      8.871448
# 9                     3.558747                      5.610138
# 10                    6.493561                     11.247178
# 11                    6.180223                     10.704461
# 12                    8.770483                     15.190922
# 13                    5.683144                      5.249324
# 14                    4.668502                      4.708772
# 15                    3.715088                      6.434722
# 16                    4.250364                      7.361846
# 17                    2.908977                      3.594009
# 18                    6.001776                      7.993972
# 19                    3.543388                      3.873904
#
#     Rolling_Mean_LST  Rolling_Stddev_LST  Rolling_Mean_AAI  \
# 0         283.669317            7.679005         -0.287823
# 1         283.636820            7.758017         -0.426385
# 2         283.587963            7.833510         -0.345919
# 3         283.516375            7.892164         -0.159093
# 4         283.483280            7.998216         -0.357413
# 5         282.900712            8.495183         -0.406773
# 6         283.525600            8.223582         -0.217691
# 7         283.605664            8.374745         -0.106631
# 8         283.590035            8.353166         -0.176963
# 9         283.561935            8.301308         -0.153326
# 10        283.577141            8.314642         -0.332326
# 11        281.917431            9.657154         -0.400815
# 12        283.546694            8.210343         -0.334810
# 13        283.588778            8.247431         -0.189499
# 14        282.905417            7.043668         -0.406591
# 15        284.232167            8.224674         -0.638293
# 16        286.031361           10.133577         -0.524077
# 17        282.964185            6.836602         -0.448140
# 18        283.834854            8.207464         -0.239117
# 19        283.920704            8.236362         -0.217146
#
#     Rolling_Stddev_AAI  Rolling_Mean_CloudFraction  \
# 0             0.483869                    0.719599
# 1             0.316991                    0.757004
# 2             0.343860                    0.768430
# 3             0.268755                    0.856576
# 4             0.178524                    0.774600
# 5             0.070077                    0.711479
# 6             0.351931                    0.844580
# 7             0.535749                    0.893003
# 8             0.229061                    0.826160
# 9             0.315730                    0.837929
# 10            0.279520                    0.706234
# 11            0.326650                    0.558031
# 12            0.201875                    0.630557
# 13            0.274478                    0.807530
# 14            0.473786                    0.662425
# 15            0.379864                    0.408303
# 16            0.349550                    0.389026
# 17            0.349013                    0.614803
# 18            0.238622                    0.810866
# 19            0.373039                    0.823775
#
#     Rolling_Stddev_CloudFraction  Rolling_Mean_NO2_strat  \
# 0                       0.139724                0.000032
# 1                       0.141170                0.000032
# 2                       0.081828                0.000033
# 3                       0.183586                0.000031
# 4                       0.097796                0.000033
# 5                       0.335296                0.000032
# 6                       0.060162                0.000032
# 7                       0.059437                0.000032
# 8                       0.109202                0.000032
# 9                       0.090406                0.000032
# 10                      0.463515                0.000032
# 11                      0.496385                0.000032
# 12                      0.345967                0.000032
# 13                      0.240253                0.000031
# 14                      0.394590                0.000032
# 15                      0.513209                0.000029
# 16                      0.527660                0.000032
# 17                      0.388489                0.000033
# 18                      0.232861                0.000030
# 19                      0.267469                0.000031
#
#     Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0                   0.000007                0.000183
# 1                   0.000007                0.000214
# 2                   0.000008                0.000172
# 3                   0.000007                0.000304
# 4                   0.000008                0.000207
# 5                   0.000008                0.000188
# 6                   0.000008                0.000206
# 7                   0.000008                0.000206
# 8                   0.000008                0.000204
# 9                   0.000008                0.000202
# 10                  0.000007                0.000186
# 11                  0.000007                0.000203
# 12                  0.000007                0.000226
# 13                  0.000006                0.000308
# 14                  0.000007                0.000304
# 15                  0.000008                0.000453
# 16                  0.000008                0.000261
# 17                  0.000007                0.000297
# 18                  0.000007                0.000354
# 19                  0.000007                0.000406
#
#     Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                   0.000121               0.000161                 0.000041
# 1                   0.000104               0.000159                 0.000040
# 2                   0.000135               0.000158                 0.000038
# 3                   0.000281               0.000156                 0.000034
# 4                   0.000129               0.000155                 0.000031
# 5                   0.000158               0.000155                 0.000031
# 6                   0.000160               0.000155                 0.000032
# 7                   0.000162               0.000155                 0.000031
# 8                   0.000160               0.000155                 0.000031
# 9                   0.000164               0.000154                 0.000030
# 10                  0.000183               0.000151                 0.000025
# 11                  0.000172               0.000133                 0.000045
# 12                  0.000163               0.000148                 0.000021
# 13                  0.000286               0.000148                 0.000020
# 14                  0.000142               0.000176                 0.000068
# 15                  0.000315               0.000228                 0.000076
# 16                  0.000135               0.000151                 0.000023
# 17                  0.000126               0.000167                 0.000048
# 18                  0.000243               0.000152                 0.000019
# 19                  0.000283               0.000155                 0.000020
#
#     Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                      17478.750221                        2648.341256
# 1                      17419.601916                        2609.250967
# 2                      17350.081865                        2567.367039
# 3                      16813.639260                        2431.513770
# 4                      17231.772274                        2508.138542
# 5                      17172.840333                        2478.232614
# 6                      17154.140200                        2477.350827
# 7                      17126.544369                        2465.640962
# 8                      17111.016002                        2463.192110
# 9                      17080.645429                        2453.268242
# 10                     17047.821962                        2446.333165
# 11                     16969.867430                        2399.760713
# 12                     16975.561494                        2441.910089
# 13                     16817.746967                        2433.693461
# 14                     16948.633955                        2427.736466
# 15                     16778.193053                        2403.964224
# 16                     16910.823022                        2409.481791
# 17                     16931.411632                        2432.458623
# 18                     16811.858457                        2429.984498
# 19                     16809.612420                        2428.827673
#
#     AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0   0.230527  280.097333        0.000024        0.000024        0.000024
# 1  -0.074006  280.097333        0.000024        0.000024        0.000024
# 2   0.024470  280.097333        0.000024        0.000024        0.000024
# 3  -0.010442  280.097333        0.000024        0.000024        0.000024
# 4  -0.176178  280.097333        0.000024        0.000024        0.000024
# 5  -0.366831  278.380000        0.000023        0.000023        0.000023
# 6   0.188599  280.097333        0.000024        0.000024        0.000024
# 7   0.507837  280.097333        0.000024        0.000024        0.000024
# 8   0.087363  280.097333        0.000024        0.000024        0.000024
# 9   0.208678  280.097333        0.000024        0.000024        0.000024
# 10 -0.633875  280.097333        0.000024        0.000024        0.000024
# 11 -0.159398  275.180000        0.000024        0.000024        0.000024
# 12 -0.204458  280.097333        0.000024        0.000024        0.000024
# 13  0.051284  280.097333        0.000024        0.000024        0.000024
# 14 -0.110994  280.097333        0.000024        0.000024        0.000024
# 15 -0.531419  281.480000        0.000023        0.000023        0.000023
# 16 -0.580316  282.980000        0.000023        0.000023        0.000023
# 17 -0.352985  280.360889        0.000024        0.000024        0.000024
# 18 -0.002400  280.464333        0.000024        0.000024        0.000024
# 19  0.121945  280.571167        0.000024        0.000024        0.000024
#
#     NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0         0.000117        0.000117        0.000117       0.000131
# 1         0.000127        0.000127        0.000127       0.000131
# 2         0.000086        0.000086        0.000086       0.000131
# 3         0.000124        0.000124        0.000124       0.000131
# 4         0.000116        0.000116        0.000116       0.000131
# 5         0.000109        0.000109        0.000109       0.000131
# 6         0.000135        0.000135        0.000135       0.000131
# 7         0.000137        0.000137        0.000137       0.000131
# 8         0.000104        0.000104        0.000104       0.000131
# 9         0.000117        0.000117        0.000117       0.000131
# 10        0.000079        0.000079        0.000079       0.000131
# 11        0.000101        0.000101        0.000101       0.000084
# 12        0.000122        0.000122        0.000122       0.000131
# 13        0.000146        0.000146        0.000146       0.000131
# 14        0.000145        0.000145        0.000145       0.000131
# 15        0.000245        0.000245        0.000245       0.000288
# 16        0.000156        0.000156        0.000156       0.000133
# 17        0.000171        0.000171        0.000171       0.000136
# 18        0.000268        0.000268        0.000268       0.000140
# 19        0.000360        0.000360        0.000360       0.000144
#
#     NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0        0.000131       0.000131              14440.82126
# 1        0.000131       0.000131              14441.79815
# 2        0.000131       0.000131              14437.38294
# 3        0.000131       0.000131              14440.83831
# 4        0.000131       0.000131              14438.79037
# 5        0.000131       0.000131              14432.05624
# 6        0.000131       0.000131              14436.70176
# 7        0.000131       0.000131              14435.01960
# 8        0.000131       0.000131              14438.51425
# 9        0.000131       0.000131              14437.71015
# 10       0.000131       0.000131              14431.63877
# 11       0.000084       0.000084              14422.64906
# 12       0.000131       0.000131              14443.86329
# 13       0.000131       0.000131              14442.95417
# 14       0.000131       0.000131              14442.46222
# 15       0.000288       0.000288              14429.31480
# 16       0.000133       0.000133              14425.69705
# 17       0.000136       0.000136              14442.65422
# 18       0.000140       0.000140              14440.19880
# 19       0.000144       0.000144              14438.88636
#
#     TropopausePressure_LAG2
# 0               14440.82126
# 1               14441.79815
# 2               14437.38294
# 3               14440.83831
# 4               14438.79037
# 5               14432.05624
# 6               14436.70176
# 7               14435.01960
# 8               14438.51425
# 9               14437.71015
# 10              14431.63877
# 11              14422.64906
# 12              14443.86329
# 13              14442.95417
# 14              14442.46222
# 15              14429.31480
# 16              14425.69705
# 17              14442.65422
# 18              14440.19880
# 19              14438.88636

# %%
for col in Skewed_cols:
    train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col]=log_transfrom_trt(train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col])

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.head(10)
# Out:
#          LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 0  45.601585  11.903551      -9.210340  280.097333  0.230527      -0.581218
# 1  45.371005  11.840830       1.114303  280.097333 -0.074006      -0.139942
# 2  45.045825  12.060869      -9.210340  280.097333  0.024470      -0.394139
# 3  45.104075  11.553241       0.182794  280.097333 -0.010442      -0.083215
# 4  45.038758  11.790152       0.242682  280.097333 -0.176178      -0.290936
# 5  45.889734  12.307124      -9.210340  278.380000 -0.366831      -1.125495
# 6  45.671721  12.237807      -9.210340  280.097333  0.188599      -0.200256
# 7  45.629092  12.590682      -9.210340  280.097333  0.507837      -0.076753
# 8  45.499618  12.261249      -9.210340  280.097333  0.087363      -0.180088
# 9  45.428424  12.312930      -0.430082  280.097333  0.208678      -0.207276
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0   0.000024  -8.382225 -8.268476         14440.82126
# 1   0.000024  -8.339466 -8.268476         14441.79815
# 2   0.000024  -8.526739 -8.268476         14437.38294
# 3   0.000024  -8.352103 -8.268476         14440.83831
# 4   0.000024  -8.386604 -8.268476         14438.79037
# 5   0.000023  -8.417800 -8.268476         14432.05624
# 6   0.000024  -8.306527 -8.268476         14436.70176
# 7   0.000024  -8.298459 -8.268476         14435.01960
# 8   0.000024  -8.440695 -8.268476         14438.51425
# 9   0.000024  -8.382225 -8.268476         14437.71015
#
#    Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  Rolling_Mean_LST  \
# 0                    1.884791                      2.434090        283.669317
# 1                    1.717735                      1.970644        283.636820
# 2                    1.381074                      1.930370        283.587963
# 3                    0.845400                      1.116339        283.516375
# 4                    1.444949                      1.836621        283.483280
# 5                    1.866805                      1.938225        282.900712
# 6                    2.150060                      2.363932        283.525600
# 7                    1.716326                      2.265625        283.605664
# 8                    1.633551                      2.182849        283.590035
# 9                    1.269437                      1.724593        283.561935
#
#    Rolling_Stddev_LST  Rolling_Mean_AAI  Rolling_Stddev_AAI  \
# 0            2.038503          1.099332           -0.725735
# 1            2.048740          1.052079           -1.148567
# 2            2.058424          1.079791           -1.067230
# 3            2.065883          1.141317           -1.313584
# 4            2.079231          1.075879           -1.722470
# 5            2.139511          1.058905           -2.656729
# 6            2.107018          1.122424           -1.044035
# 7            2.125233          1.157935           -0.623903
# 8            2.122653          1.135593           -1.473329
# 9            2.116425          1.143158           -1.152550
#
#    Rolling_Mean_CloudFraction  Rolling_Stddev_CloudFraction  \
# 0                   -0.328923                     -1.967372
# 1                   -0.278255                     -1.957082
# 2                   -0.263276                     -2.501912
# 3                   -0.154695                     -1.694526
# 4                   -0.255280                     -2.323850
# 5                   -0.340269                     -1.092445
# 6                   -0.168797                     -2.809058
# 7                   -0.113053                     -2.821164
# 8                   -0.190845                     -2.213637
# 9                   -0.176703                     -2.402338
#
#    Rolling_Mean_NO2_strat  Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0                0.000032                 -9.139920               -8.168800
# 1                0.000032                 -9.138728               -8.065476
# 2                0.000033                 -9.135579               -8.208074
# 3                0.000031                 -9.146313               -7.814921
# 4                0.000033                 -9.135782               -8.089858
# 5                0.000032                 -9.137187               -8.152338
# 6                0.000032                 -9.137828               -8.092234
# 7                0.000032                 -9.137338               -8.090530
# 8                0.000032                 -9.137289               -8.098633
# 9                0.000032                 -9.137530               -8.105916
#
#    Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                 -8.417132              -8.251292                -8.864902
# 1                 -8.496386              -8.257614                -8.874134
# 2                 -8.355529              -8.261479                -8.888280
# 3                 -7.873780              -8.269990                -8.920634
# 4                 -8.383253              -8.276172                -8.943668
# 5                 -8.260812              -8.274299                -8.937191
# 6                 -8.255500              -8.273439                -8.934068
# 7                 -8.245707              -8.275722                -8.941309
# 8                 -8.253633              -8.274293                -8.936575
# 9                 -8.237994              -8.278622                -8.950891
#
#    Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                     17478.750221                           7.881689
# 1                     17419.601916                           7.866819
# 2                     17350.081865                           7.850636
# 3                     16813.639260                           7.796269
# 4                     17231.772274                           7.827296
# 5                     17172.840333                           7.815301
# 6                     17154.140200                           7.814945
# 7                     17126.544369                           7.810207
# 8                     17111.016002                           7.809213
# 9                     17080.645429                           7.805176
#
#    AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0  0.230527  280.097333        0.000024        0.000024        0.000024
# 1 -0.074006  280.097333        0.000024        0.000024        0.000024
# 2  0.024470  280.097333        0.000024        0.000024        0.000024
# 3 -0.010442  280.097333        0.000024        0.000024        0.000024
# 4 -0.176178  280.097333        0.000024        0.000024        0.000024
# 5 -0.366831  278.380000        0.000023        0.000023        0.000023
# 6  0.188599  280.097333        0.000024        0.000024        0.000024
# 7  0.507837  280.097333        0.000024        0.000024        0.000024
# 8  0.087363  280.097333        0.000024        0.000024        0.000024
# 9  0.208678  280.097333        0.000024        0.000024        0.000024
#
#    NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0       -8.382225       -8.382225       -8.382225      -8.268476
# 1       -8.339466       -8.339466       -8.339466      -8.268476
# 2       -8.526739       -8.526739       -8.526739      -8.268476
# 3       -8.352103       -8.352103       -8.352103      -8.268476
# 4       -8.386604       -8.386604       -8.386604      -8.268476
# 5       -8.417800       -8.417800       -8.417800      -8.268476
# 6       -8.306527       -8.306527       -8.306527      -8.268476
# 7       -8.298459       -8.298459       -8.298459      -8.268476
# 8       -8.440695       -8.440695       -8.440695      -8.268476
# 9       -8.382225       -8.382225       -8.382225      -8.268476
#
#    NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0      -8.268476      -8.268476              14440.82126
# 1      -8.268476      -8.268476              14441.79815
# 2      -8.268476      -8.268476              14437.38294
# 3      -8.268476      -8.268476              14440.83831
# 4      -8.268476      -8.268476              14438.79037
# 5      -8.268476      -8.268476              14432.05624
# 6      -8.268476      -8.268476              14436.70176
# 7      -8.268476      -8.268476              14435.01960
# 8      -8.268476      -8.268476              14438.51425
# 9      -8.268476      -8.268476              14437.71015
#
#    TropopausePressure_LAG2
# 0              14440.82126
# 1              14441.79815
# 2              14437.38294
# 3              14440.83831
# 4              14438.79037
# 5              14432.05624
# 6              14436.70176
# 7              14435.01960
# 8              14438.51425
# 9              14437.71015

# %%
skew_incr=[]
for col in Skewed_cols:
    print('Before:',col,train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[col])
    print('After:',col,train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.skew()[col])
    if not abs(train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[col])>abs(train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.skew()[col]):
        skew_incr.append(col)
    print('\n')
# Out:
# Before: Precipitation 4.569618429259263
# After: Precipitation 1.5171822647199633
#
#
# Before: CloudFraction 1.2368812312528774
# After: CloudFraction -1.4714216645089138
#
#
# Before: NO2_total 4.169192733648738
# After: NO2_total 1.6688966196282646
#
#
# Before: NO2_trop 2.935213957795029
# After: NO2_trop 1.3232412318536575
#
#
# Before: Rolling_Mean_Precipitation 2.702030626182702
# After: Rolling_Mean_Precipitation 0.2614906171333378
#
#
# Before: Rolling_Stddev_Precipitation 2.7934187108952053
# After: Rolling_Stddev_Precipitation 0.2582753345866494
#
#
# Before: Rolling_Stddev_LST 1.407022882161994
# After: Rolling_Stddev_LST -0.6201144706329049
#
#
# Before: Rolling_Mean_AAI 0.5585953628123189
# After: Rolling_Mean_AAI -0.794397295904864
#
#
# Before: Rolling_Stddev_AAI 1.204749435254367
# After: Rolling_Stddev_AAI -0.8403124994451319
#
#
# Before: Rolling_Mean_CloudFraction 0.8243970114592594
# After: Rolling_Mean_CloudFraction -2.26457274415614
#
#
# Before: Rolling_Stddev_CloudFraction 0.507064503175373
# After: Rolling_Stddev_CloudFraction -1.9032227915477735
#
#
# Before: Rolling_Stddev_NO2_strat 1.383593386266386
# After: Rolling_Stddev_NO2_strat 1.2553984439680619
#
#
# Before: Rolling_Mean_NO2_total 2.8552433803339774
# After: Rolling_Mean_NO2_total 1.3952458634231528
#
#
# Before: Rolling_Stddev_NO2_total 4.382217297092999
# After: Rolling_Stddev_NO2_total 1.7125693551922305
#
#
# Before: Rolling_Mean_NO2_trop 2.107715578643439
# After: Rolling_Mean_NO2_trop 1.0089976488207435
#
#
# Before: Rolling_Stddev_NO2_trop 2.970711497405898
# After: Rolling_Stddev_NO2_trop 1.6609308940889187
#
#
# Before: Rolling_Stddev_TropopausePressure 0.8066263954114595
# After: Rolling_Stddev_TropopausePressure -2.131191074793983
#
#
# Before: NO2_total_LAG1 4.17966202758049
# After: NO2_total_LAG1 1.665928260762061
#
#
# Before: NO2_total_LAG2 4.183827230239358
# After: NO2_total_LAG2 1.666539991257061
#
#
# Before: NO2_total_LAG3 4.180559298784405
# After: NO2_total_LAG3 1.6657853500514845
#
#
# Before: NO2_trop_LAG1 2.9372947596862558
# After: NO2_trop_LAG1 1.323637602256939
#
#
# Before: NO2_trop_LAG2 2.937191178993661
# After: NO2_trop_LAG2 1.3223075848060541
#
#
# Before: NO2_trop_LAG3 2.934674900416164
# After: NO2_trop_LAG3 1.3212600991299241

# %%
#Skewness incresead for these cols. We will do sqrt instead
print(skew_incr)
for col in skew_incr:
    train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col]=train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1[col].copy()
# Out:
# ['CloudFraction', 'Rolling_Mean_AAI', 'Rolling_Mean_CloudFraction', 'Rolling_Stddev_CloudFraction', 'Rolling_Stddev_TropopausePressure']

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[skew_incr].describe().T
# Out:
#                                      count         mean          std  \
# CloudFraction                      86584.0     0.238371     0.274434
# Rolling_Mean_AAI                   86584.0    -1.255426     0.534608
# Rolling_Mean_CloudFraction         86584.0     0.238663     0.180119
# Rolling_Stddev_CloudFraction       86584.0     0.202189     0.153922
# Rolling_Stddev_TropopausePressure  86584.0  1905.627055  1376.214490
#
#                                         min          25%          50%  \
# CloudFraction                      0.000000     0.030640     0.112237
# Rolling_Mean_AAI                  -3.289884    -1.630519    -1.322073
# Rolling_Mean_CloudFraction         0.000000     0.086085     0.208139
# Rolling_Stddev_CloudFraction       0.000000     0.063585     0.170843
# Rolling_Stddev_TropopausePressure  0.000000  1153.349783  1499.896124
#
#                                            75%          max
# CloudFraction                         0.372591     1.000000
# Rolling_Mean_AAI                     -0.950591     0.769099
# Rolling_Mean_CloudFraction            0.351432     0.976606
# Rolling_Stddev_CloudFraction          0.322412     0.577350
# Rolling_Stddev_TropopausePressure  2722.220593  7291.919792

# %%
#Org skewness
train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[skew_incr].skew()
# Out:
# CloudFraction                        1.236881
# Rolling_Mean_AAI                     0.558595
# Rolling_Mean_CloudFraction           0.824397
# Rolling_Stddev_CloudFraction         0.507065
# Rolling_Stddev_TropopausePressure    0.806626
# dtype: float64

# %%
for col in skew_incr:
    train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col]=np.sqrt(train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col].abs())

# %%
print(train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[skew_incr].skew())
#Lets leave  Rolling_Mean_AAI as it is and not screw it up
Sqrt_trt_col_skew=skew_incr
Sqrt_trt_col_skew.remove('Rolling_Mean_AAI')
print(Sqrt_trt_col_skew)
# Out:
# CloudFraction                        0.470742
# Rolling_Mean_AAI                    -1.152743
# Rolling_Mean_CloudFraction          -0.016732
# Rolling_Stddev_CloudFraction        -0.097127
# Rolling_Stddev_TropopausePressure   -0.516428
# dtype: float64
# ['CloudFraction', 'Rolling_Mean_CloudFraction', 'Rolling_Stddev_CloudFraction', 'Rolling_Stddev_TropopausePressure']

# %%
for col in skew_incr:
    Skewed_cols.remove(col)

# %%
Skewed_cols.remove('Rolling_Mean_AAI')

# %%
Log_trt_col_Skew=Skewed_cols
print(Sqrt_trt_col_skew)
print('\n')
print(Log_trt_col_Skew)
# Out:
# ['CloudFraction', 'Rolling_Mean_CloudFraction', 'Rolling_Stddev_CloudFraction', 'Rolling_Stddev_TropopausePressure']
#
#
# ['Precipitation', 'NO2_total', 'NO2_trop', 'Rolling_Mean_Precipitation', 'Rolling_Stddev_Precipitation', 'Rolling_Stddev_LST', 'Rolling_Stddev_AAI', 'Rolling_Stddev_NO2_strat', 'Rolling_Mean_NO2_total', 'Rolling_Stddev_NO2_total', 'Rolling_Mean_NO2_trop', 'Rolling_Stddev_NO2_trop', 'NO2_total_LAG1', 'NO2_total_LAG2', 'NO2_total_LAG3', 'NO2_trop_LAG1', 'NO2_trop_LAG2', 'NO2_trop_LAG3']

# %%
for col in Log_trt_col_Skew:
    print('Before:',col,train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[col])
    print('After:',col,train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.skew()[col])

    print('\n')
# Out:
# Before: Precipitation 4.569618429259263
# After: Precipitation 1.5171822647199633
#
#
# Before: NO2_total 4.169192733648738
# After: NO2_total 1.6688966196282646
#
#
# Before: NO2_trop 2.935213957795029
# After: NO2_trop 1.3232412318536575
#
#
# Before: Rolling_Mean_Precipitation 2.702030626182702
# After: Rolling_Mean_Precipitation 0.2614906171333378
#
#
# Before: Rolling_Stddev_Precipitation 2.7934187108952053
# After: Rolling_Stddev_Precipitation 0.2582753345866494
#
#
# Before: Rolling_Stddev_LST 1.407022882161994
# After: Rolling_Stddev_LST -0.6201144706329049
#
#
# Before: Rolling_Stddev_AAI 1.204749435254367
# After: Rolling_Stddev_AAI -0.8403124994451319
#
#
# Before: Rolling_Stddev_NO2_strat 1.383593386266386
# After: Rolling_Stddev_NO2_strat 1.2553984439680619
#
#
# Before: Rolling_Mean_NO2_total 2.8552433803339774
# After: Rolling_Mean_NO2_total 1.3952458634231528
#
#
# Before: Rolling_Stddev_NO2_total 4.382217297092999
# After: Rolling_Stddev_NO2_total 1.7125693551922305
#
#
# Before: Rolling_Mean_NO2_trop 2.107715578643439
# After: Rolling_Mean_NO2_trop 1.0089976488207435
#
#
# Before: Rolling_Stddev_NO2_trop 2.970711497405898
# After: Rolling_Stddev_NO2_trop 1.6609308940889187
#
#
# Before: NO2_total_LAG1 4.17966202758049
# After: NO2_total_LAG1 1.665928260762061
#
#
# Before: NO2_total_LAG2 4.183827230239358
# After: NO2_total_LAG2 1.666539991257061
#
#
# Before: NO2_total_LAG3 4.180559298784405
# After: NO2_total_LAG3 1.6657853500514845
#
#
# Before: NO2_trop_LAG1 2.9372947596862558
# After: NO2_trop_LAG1 1.323637602256939
#
#
# Before: NO2_trop_LAG2 2.937191178993661
# After: NO2_trop_LAG2 1.3223075848060541
#
#
# Before: NO2_trop_LAG3 2.934674900416164
# After: NO2_trop_LAG3 1.3212600991299241

# %%
for col in Sqrt_trt_col_skew:
    print('Before:',col,train_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[col])
    print('After:',col,train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.skew()[col])

    print('\n')

#Final Train for Model 6: train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1
# Out:
# Before: CloudFraction 1.2368812312528774
# After: CloudFraction 0.4707422286390351
#
#
# Before: Rolling_Mean_CloudFraction 0.8243970114592594
# After: Rolling_Mean_CloudFraction -0.016731679621355043
#
#
# Before: Rolling_Stddev_CloudFraction 0.507064503175373
# After: Rolling_Stddev_CloudFraction -0.09712652807714382
#
#
# Before: Rolling_Stddev_TropopausePressure 0.8066263954114595
# After: Rolling_Stddev_TropopausePressure -0.5164283952433941

# %%
train_model3_df_prep_mix_GT_NO2_mix.isnull().sum()
# Out:
# 0

# %%
# #Now treating GT_NO2

print('Before treatement',train_model3_df_prep_mix_GT_NO2_mix.skew())
train_model3_df_prep_mix_skew_trt_GT_NO2=np.log1p(train_model3_df_prep_mix_GT_NO2_mix)
print('After treatement',train_model3_df_prep_mix_skew_trt_GT_NO2.skew())
# Out:
# Before treatement 1.4995334759205738
# After treatement -0.19615003960412955

# %%
#Checkpoint: #Final GT_NO2 for Model 6: train_model3_df_prep_mix_skew_trt_GT_NO2
#Final Train for Model 6: train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1=test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.copy()

# %%
#Now treating skewness in Test in similar way # First doing long
for col in Log_trt_col_Skew:
    test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col]=log_transfrom_trt(test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col])

# %%
#Now doing sqrt treatment
for col in Sqrt_trt_col_skew:
    test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col]=np.sqrt(test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1[col].abs())

# %%
for col in Log_trt_col_Skew:
    print('Before:',col,test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[col])
    print('After:',col,test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.skew()[col])

    print('\n')
# Out:
# Before: Precipitation 4.409900124327067
# After: Precipitation 1.5310861116506305
#
#
# Before: NO2_total 5.237289466539959
# After: NO2_total 1.987697663090459
#
#
# Before: NO2_trop 3.275637690439222
# After: NO2_trop 1.37284394791529
#
#
# Before: Rolling_Mean_Precipitation 2.613215098283561
# After: Rolling_Mean_Precipitation 0.3764374593092157
#
#
# Before: Rolling_Stddev_Precipitation 2.7567998292347546
# After: Rolling_Stddev_Precipitation 0.3780436004704904
#
#
# Before: Rolling_Stddev_LST 2.293981682270173
# After: Rolling_Stddev_LST -0.8802842147816398
#
#
# Before: Rolling_Stddev_AAI 1.3586385217712897
# After: Rolling_Stddev_AAI -1.0498045254475055
#
#
# Before: Rolling_Stddev_NO2_strat 1.3276459016380369
# After: Rolling_Stddev_NO2_strat 1.261921769810858
#
#
# Before: Rolling_Mean_NO2_total 4.225154105376492
# After: Rolling_Mean_NO2_total 1.8364780780513235
#
#
# Before: Rolling_Stddev_NO2_total 5.097974453526616
# After: Rolling_Stddev_NO2_total 2.2955603937824116
#
#
# Before: Rolling_Mean_NO2_trop 1.9713487193928567
# After: Rolling_Mean_NO2_trop 1.0593274854588919
#
#
# Before: Rolling_Stddev_NO2_trop 4.451370200711404
# After: Rolling_Stddev_NO2_trop 2.4670323654030173
#
#
# Before: NO2_total_LAG1 5.250820896319968
# After: NO2_total_LAG1 1.9778652937374
#
#
# Before: NO2_total_LAG2 5.2595390146108185
# After: NO2_total_LAG2 1.9766737033367736
#
#
# Before: NO2_total_LAG3 5.256695917399093
# After: NO2_total_LAG3 1.9774541065830924
#
#
# Before: NO2_trop_LAG1 3.2765984363188094
# After: NO2_trop_LAG1 1.3730835650185036
#
#
# Before: NO2_trop_LAG2 3.262121026000272
# After: NO2_trop_LAG2 1.3639774483061267
#
#
# Before: NO2_trop_LAG3 3.262188106767333
# After: NO2_trop_LAG3 1.364137309182941

# %%
for col in Sqrt_trt_col_skew:
    print('Before:',col,test_model3_df_prep_mix_roll_wind_mean_stddev_org_v1.skew()[col])
    print('After:',col,test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.skew()[col])

    print('\n')
# Out:
# Before: CloudFraction 1.29561885475446
# After: CloudFraction 0.44339351502902985
#
#
# Before: Rolling_Mean_CloudFraction 0.9783771484616129
# After: Rolling_Mean_CloudFraction 0.11265560819866258
#
#
# Before: Rolling_Stddev_CloudFraction 0.8841065626851445
# After: Rolling_Stddev_CloudFraction 0.13377003963794548
#
#
# Before: Rolling_Stddev_TropopausePressure 0.8066432331630113
# After: Rolling_Stddev_TropopausePressure -0.5472115449680394

# %%
#Checkpoint: #Final GT_NO2 for Model 6: train_model3_df_prep_mix_skew_trt_GT_NO2
#Final Train for Model 6: train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1
#Final Test for Model 6: test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1

# %%
#Before treating for scaling  lets create a model

model= LinearRegression()
model.fit(train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1, train_model3_df_prep_mix_skew_trt_GT_NO2)

# Predict using the test dataset
y_pred = model.predict(test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1)
y_pred=np.expm1(y_pred)
# Add additional 'ID_Zindi' to y_pred3 and create a DataFrame
y_pred_df = pd.DataFrame(y_pred, columns=['GT_NO2'])
y_pred_result_df = pd.concat([test_df['ID_Zindi'], y_pred_df], axis=1)

# Save the results to a CSV file
y_pred_result_df.to_csv('/home/anuragverma/Desktop/Kaggle/GeoAI Ground-level NO2 _Zindi/model6_lag_roll_skew_trt.csv', index=False)

#This worsened the model 11.15. Will check if scaling helps.

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for alpha
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# Initialize Ridge Regression model
ridge_model = Ridge()

# Initialize GridSearchCV with the model and parameter grid
grid_search = GridSearchCV(ridge_model, param_grid, cv=5)

# Fit the grid search to the data
grid_search.fit(train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1, train_model3_df_prep_mix_skew_trt_GT_NO2)

# Get the best alpha value
best_alpha = grid_search.best_params_['alpha']

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1)
y_pred = np.expm1(y_pred)

# Add additional 'ID_Zindi' to y_pred and create a DataFrame
y_pred_df = pd.DataFrame(y_pred, columns=['GT_NO2'])
y_pred_result_df = pd.concat([test_df['ID_Zindi'], y_pred_df], axis=1)

# Save the results to a CSV file
y_pred_result_df.to_csv('/home/anuragverma/Desktop/Kaggle/GeoAI Ground-level NO2 _Zindi/model6_lag_roll_skew_trt_best.csv', index=False)
#Gave 11.48

# %%
#Trying Lasso
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for alpha
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# Initialize Lasso Regression model
lasso_model = Lasso()

# Initialize GridSearchCV with the model and parameter grid
grid_search = GridSearchCV(lasso_model, param_grid, cv=5)

# Fit the grid search to the data
grid_search.fit(train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1, train_model3_df_prep_mix_skew_trt_GT_NO2)

# Get the best alpha value
best_alpha = grid_search.best_params_['alpha']

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1)
y_pred = np.expm1(y_pred)

# Add additional 'ID_Zindi' to y_pred and create a DataFrame
y_pred_df = pd.DataFrame(y_pred, columns=['GT_NO2'])
y_pred_result_df = pd.concat([test_df['ID_Zindi'], y_pred_df], axis=1)

# Save the results to a CSV file
y_pred_result_df.to_csv('/home/anuragverma/Desktop/Kaggle/GeoAI Ground-level NO2 _Zindi/model6_lag_roll_skew_trt_lasso.csv', index=False)

#11.80

# %%
#We will continue scaling the log version .Let's see if it takes us to the moon.
#Checkpoint: #Final GT_NO2 for Model 6: train_model3_df_prep_mix_skew_trt_GT_NO2
#Final Train for Model 6: train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1
#Final Test for Model 6: test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1
# Out:
# Ridge(alpha=0.001)

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.head(5)
# Out:
#          LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 0  45.601585  11.903551      -9.210340  280.097333  0.230527       0.747741
# 1  45.371005  11.840830       1.114303  280.097333 -0.074006       0.932367
# 2  45.045825  12.060869      -9.210340  280.097333  0.024470       0.821073
# 3  45.104075  11.553241       0.182794  280.097333 -0.010442       0.959194
# 4  45.038758  11.790152       0.242682  280.097333 -0.176178       0.864560
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0   0.000024  -8.382225 -8.268476         14440.82126
# 1   0.000024  -8.339466 -8.268476         14441.79815
# 2   0.000024  -8.526739 -8.268476         14437.38294
# 3   0.000024  -8.352103 -8.268476         14440.83831
# 4   0.000024  -8.386604 -8.268476         14438.79037
#
#    Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  Rolling_Mean_LST  \
# 0                    1.884791                      2.434090        283.669317
# 1                    1.717735                      1.970644        283.636820
# 2                    1.381074                      1.930370        283.587963
# 3                    0.845400                      1.116339        283.516375
# 4                    1.444949                      1.836621        283.483280
#
#    Rolling_Stddev_LST  Rolling_Mean_AAI  Rolling_Stddev_AAI  \
# 0            2.038503          0.536492           -0.725735
# 1            2.048740          0.652982           -1.148567
# 2            2.058424          0.588149           -1.067230
# 3            2.065883          0.398865           -1.313584
# 4            2.079231          0.597840           -1.722470
#
#    Rolling_Mean_CloudFraction  Rolling_Stddev_CloudFraction  \
# 0                    0.848292                      0.373797
# 1                    0.870060                      0.375726
# 2                    0.876601                      0.286056
# 3                    0.925514                      0.428470
# 4                    0.880114                      0.312723
#
#    Rolling_Mean_NO2_strat  Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0                0.000032                 -9.139920               -8.168800
# 1                0.000032                 -9.138728               -8.065476
# 2                0.000033                 -9.135579               -8.208074
# 3                0.000031                 -9.146313               -7.814921
# 4                0.000033                 -9.135782               -8.089858
#
#    Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                 -8.417132              -8.251292                -8.864902
# 1                 -8.496386              -8.257614                -8.874134
# 2                 -8.355529              -8.261479                -8.888280
# 3                 -7.873780              -8.269990                -8.920634
# 4                 -8.383253              -8.276172                -8.943668
#
#    Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                     17478.750221                          51.462037
# 1                     17419.601916                          51.080828
# 2                     17350.081865                          50.669192
# 3                     16813.639260                          49.310382
# 4                     17231.772274                          50.081319
#
#    AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0  0.230527  280.097333        0.000024        0.000024        0.000024
# 1 -0.074006  280.097333        0.000024        0.000024        0.000024
# 2  0.024470  280.097333        0.000024        0.000024        0.000024
# 3 -0.010442  280.097333        0.000024        0.000024        0.000024
# 4 -0.176178  280.097333        0.000024        0.000024        0.000024
#
#    NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0       -8.382225       -8.382225       -8.382225      -8.268476
# 1       -8.339466       -8.339466       -8.339466      -8.268476
# 2       -8.526739       -8.526739       -8.526739      -8.268476
# 3       -8.352103       -8.352103       -8.352103      -8.268476
# 4       -8.386604       -8.386604       -8.386604      -8.268476
#
#    NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0      -8.268476      -8.268476              14440.82126
# 1      -8.268476      -8.268476              14441.79815
# 2      -8.268476      -8.268476              14437.38294
# 3      -8.268476      -8.268476              14440.83831
# 4      -8.268476      -8.268476              14438.79037
#
#    TropopausePressure_LAG2
# 0              14440.82126
# 1              14441.79815
# 2              14437.38294
# 3              14440.83831
# 4              14438.79037

# %%
Columns_to_rescale=[col for col in train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.columns]
Columns_to_rescale.remove('LAT')
Columns_to_rescale.remove('LON')

# %%
print(Columns_to_rescale)
# Out:
# ['Precipitation', 'LST', 'AAI', 'CloudFraction', 'NO2_strat', 'NO2_total', 'NO2_trop', 'TropopausePressure', 'Rolling_Mean_Precipitation', 'Rolling_Stddev_Precipitation', 'Rolling_Mean_LST', 'Rolling_Stddev_LST', 'Rolling_Mean_AAI', 'Rolling_Stddev_AAI', 'Rolling_Mean_CloudFraction', 'Rolling_Stddev_CloudFraction', 'Rolling_Mean_NO2_strat', 'Rolling_Stddev_NO2_strat', 'Rolling_Mean_NO2_total', 'Rolling_Stddev_NO2_total', 'Rolling_Mean_NO2_trop', 'Rolling_Stddev_NO2_trop', 'Rolling_Mean_TropopausePressure', 'Rolling_Stddev_TropopausePressure', 'AAI_LAG3', 'LST_LAG1', 'NO2_strat_LAG1', 'NO2_strat_LAG2', 'NO2_strat_LAG3', 'NO2_total_LAG1', 'NO2_total_LAG2', 'NO2_total_LAG3', 'NO2_trop_LAG1', 'NO2_trop_LAG2', 'NO2_trop_LAG3', 'TropopausePressure_LAG1', 'TropopausePressure_LAG2']

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1=train_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.copy()

# %%
scaler=StandardScaler()
train_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1[Columns_to_rescale]=scaler.fit_transform(train_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1[Columns_to_rescale])

# %%
train_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1.head(4)
# Out:
#          LAT        LON  Precipitation       LST       AAI  CloudFraction  \
# 0  45.601585  11.903551      -0.503912 -1.360332  2.114154       1.235104
# 1  45.371005  11.840830       1.765684 -1.360332  1.680799       1.885906
# 2  45.045825  12.060869      -0.503912 -1.360332  1.820932       1.493595
# 3  45.104075  11.553241       1.560917 -1.360332  1.771252       1.980470
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0  -1.830742  -0.452184  0.572214           -0.769145
# 1  -1.822100  -0.291999  0.572214           -0.768821
# 2  -1.813458  -0.993555  0.572214           -0.770285
# 3  -1.804815  -0.339339  0.572214           -0.769139
#
#    Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  Rolling_Mean_LST  \
# 0                    1.214188                      1.246431         -1.193435
# 1                    1.182434                      1.161235         -1.196632
# 2                    1.118441                      1.153832         -1.201438
# 3                    1.016620                      1.004187         -1.208481
#
#    Rolling_Stddev_LST  Rolling_Mean_AAI  Rolling_Stddev_AAI  \
# 0            0.806175         -2.054840            0.355511
# 1            0.817607         -1.623276           -0.211639
# 2            0.828422         -1.863464           -0.102541
# 3            0.836752         -2.564710           -0.432979
#
#    Rolling_Mean_CloudFraction  Rolling_Stddev_CloudFraction  \
# 0                    2.046380                     -0.184767
# 1                    2.157544                     -0.174498
# 2                    2.190949                     -0.651726
# 3                    2.440733                      0.106206
#
#    Rolling_Mean_NO2_strat  Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0               -1.265506                  0.479609                0.542183
# 1               -1.238542                  0.509566                0.985481
# 2               -1.188292                  0.588704                0.373688
# 3               -1.352251                  0.318949                2.060443
#
#    Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                  1.539002               1.134472                 0.245224
# 1                  1.267091               1.108509                 0.206654
# 2                  1.750352               1.092640                 0.147554
# 3                  3.403172               1.057693                 0.012382
#
#    Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                         0.306788                           0.641994
# 1                         0.281344                           0.621682
# 2                         0.251439                           0.599750
# 3                         0.020681                           0.527350
#
#    AAI_LAG3  LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0  2.121276 -1.360036       -1.828370       -1.824989       -1.820979
# 1  1.686697 -1.360036       -1.819736       -1.816366       -1.812368
# 2  1.827226 -1.360036       -1.811101       -1.807743       -1.803757
# 3  1.777406 -1.360036       -1.802467       -1.799120       -1.795147
#
#    NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0       -0.451985       -0.451752       -0.451738       0.572723
# 1       -0.291452       -0.291131       -0.291173       0.572723
# 2       -0.994530       -0.994597       -0.994391       0.572723
# 3       -0.338896       -0.338600       -0.338626       0.572723
#
#    NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0        0.57368       0.573152                -0.769881
# 1        0.57368       0.573152                -0.769557
# 2        0.57368       0.573152                -0.771021
# 3        0.57368       0.573152                -0.769875
#
#    TropopausePressure_LAG2
# 0                -0.770612
# 1                -0.770287
# 2                -0.771753
# 3                -0.770606

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1=test_model3_df_prep_mix_roll_wind_mean_stddev_org_skew_trt_v1.copy()

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1.head(3)
# Out:
#          LAT        LON  Precipitation         LST       AAI  CloudFraction  \
# 0  45.289376  11.642394        1.18712  279.369667 -0.313361       0.878326
# 1  45.836941  12.510362       -9.21034  279.369667 -0.229512       0.631038
# 2  45.582894   8.842165       -9.21034  282.980000 -0.470822       0.392039
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0   0.000024  -8.649012 -8.406815         14440.02819
# 1   0.000023  -8.421883 -8.406815         14434.04790
# 2   0.000023  -8.213392 -8.266590         14427.42478
#
#    Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  Rolling_Mean_LST  \
# 0                    0.088569                      0.637836        278.209889
# 1                   -9.210340                     -9.210340        280.769889
# 2                   -9.210340                     -9.210340        282.366667
#
#    Rolling_Stddev_LST  Rolling_Mean_AAI  Rolling_Stddev_AAI  \
# 0            1.279080         -0.402533           -1.270156
# 1            0.408316         -0.528932           -1.311679
# 2            0.488045         -0.679175           -1.695247
#
#    Rolling_Mean_CloudFraction  Rolling_Stddev_CloudFraction  \
# 0                    0.559280                      0.637093
# 1                    0.384795                      0.466740
# 2                    0.226344                      0.297885
#
#    Rolling_Mean_NO2_strat  Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0                0.000029                 -9.166267               -8.571297
# 1                0.000028                 -9.167649               -8.491688
# 2                0.000028                 -9.164888               -8.216101
#
#    Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                 -8.919476              -8.685060                -8.870042
# 1                 -8.905468              -8.602787                -8.841280
# 2                 -8.536875              -8.324371                -8.525659
#
#    Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                     19153.006053                          64.397214
# 1                     19131.785407                          64.305575
# 2                     18626.888577                          62.582412
#
#    AAI_LAG3    LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0 -0.313361  279.369667        0.000024        0.000024        0.000024
# 1 -0.229512  279.369667        0.000023        0.000023        0.000023
# 2 -0.470822  282.980000        0.000023        0.000023        0.000023
#
#    NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0       -8.649012       -8.649012       -8.649012      -8.406815
# 1       -8.421883       -8.421883       -8.421883      -8.406815
# 2       -8.213392       -8.213392       -8.213392      -8.266590
#
#    NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0      -8.406815      -8.406815              14440.02819
# 1      -8.406815      -8.406815              14434.04790
# 2      -8.266590      -8.266590              14427.42478
#
#    TropopausePressure_LAG2
# 0              14440.02819
# 1              14434.04790
# 2              14427.42478

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1[Columns_to_rescale]=scaler.transform(test_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1[Columns_to_rescale])

# %%
test_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1.head(3)
# Out:
#          LAT        LON  Precipitation       LST       AAI  CloudFraction  \
# 0  45.289376  11.642394       1.792713 -1.615027  1.406310       1.753055
# 1  45.836941  12.510362      -0.501195 -1.615027  1.531781       0.890988
# 2  45.582894   8.842165      -0.501195 -1.283065  1.170688       0.057819
#
#    NO2_strat  NO2_total  NO2_trop  TropopausePressure  \
# 0  -1.723963  -1.104863  0.788145           -0.796123
# 1  -1.774430  -0.163627  0.788145           -0.798146
# 2  -1.816487   0.700374  1.392296           -0.800386
#
#    Rolling_Mean_Precipitation  Rolling_Stddev_Precipitation  Rolling_Mean_LST  \
# 0                    0.928436                      0.982758         -1.758289
# 1                   -0.843652                     -0.841472         -1.517871
# 2                   -0.843652                     -0.841472         -1.367912
#
#    Rolling_Stddev_LST  Rolling_Mean_AAI  Rolling_Stddev_AAI  \
# 0            0.964441          1.536515           -0.029301
# 1            0.055584          1.308294           -0.080187
# 2            0.138801          1.037021           -0.550253
#
#    Rolling_Mean_CloudFraction  Rolling_Stddev_CloudFraction  \
# 0                    0.646826                      1.454999
# 1                   -0.174260                      0.538688
# 2                   -0.919894                     -0.369566
#
#    Rolling_Mean_NO2_strat  Rolling_Stddev_NO2_strat  Rolling_Mean_NO2_total  \
# 0               -1.364856                  1.129595               -0.938638
# 1               -1.456659                  1.045610               -0.560488
# 2               -1.456659                  1.213359                0.748562
#
#    Rolling_Stddev_NO2_total  Rolling_Mean_NO2_trop  Rolling_Stddev_NO2_trop  \
# 0                  0.157977              -0.231199                 0.907251
# 1                  0.215411               0.141367                 1.065740
# 2                  1.726611               1.402157                 2.804952
#
#    Rolling_Mean_TropopausePressure  Rolling_Stddev_TropopausePressure  \
# 0                         0.904748                           1.844955
# 1                         0.896586                           1.839521
# 2                         0.702381                           1.737331
#
#    AAI_LAG3  LST_LAG1  NO2_strat_LAG1  NO2_strat_LAG2  NO2_strat_LAG3  \
# 0  1.405111 -1.614742       -1.721605       -1.718410       -1.715118
# 1  1.530526 -1.614742       -1.772025       -1.768769       -1.765414
# 2  1.169594 -1.282816       -1.814042       -1.810734       -1.807327
#
#    NO2_total_LAG1  NO2_total_LAG2  NO2_total_LAG3  NO2_trop_LAG1  \
# 0       -1.106786       -1.107048       -1.106387       0.788325
# 1       -0.162665       -0.162126       -0.161741       0.788325
# 2        0.703984        0.705258        0.705390       1.392548
#
#    NO2_trop_LAG2  NO2_trop_LAG3  TropopausePressure_LAG1  \
# 0       0.790129       0.790158                -0.796687
# 1       0.790129       0.790158                -0.798710
# 2       1.395366       1.395397                -0.800951
#
#    TropopausePressure_LAG2
# 0                -0.796832
# 1                -0.798856
# 2                -0.801097

# %%
#Checkpoint
#train: train_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1
#test: test_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1
#Final GT_NO2 for Model 6: train_model3_df_prep_mix_skew_trt_GT_NO2

# %%
#Lets create model 
model= LinearRegression()
model.fit(train_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1, train_model3_df_prep_mix_skew_trt_GT_NO2)

# Predict using the test dataset
y_pred = model.predict(test_model3_df_prep_mix_roll_wind_mean_stddev_org_scaled_v1)
y_pred=np.expm1(y_pred)
# Add additional 'ID_Zindi' to y_pred3 and create a DataFrame
y_pred_df = pd.DataFrame(y_pred, columns=['GT_NO2'])
y_pred_result_df = pd.concat([test_df['ID_Zindi'], y_pred_df], axis=1)

# Save the results to a CSV file
y_pred_result_df.to_csv('/home/anuragverma/Desktop/Kaggle/GeoAI Ground-level NO2 _Zindi/model7_scaled.csv', index=False)
#Scaling made it worst: 11.80
